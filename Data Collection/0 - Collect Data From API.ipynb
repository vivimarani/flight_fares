# %% [markdown]
# ### Outline
# This is the first stage of the project. We need to connect to a API to collect data. We will call Google's QPX Express API every 30 minutes through a cron job in the EC2 instance, and store the JSON response data in AWS S3.
#
# * 1) Get API credentials
# * 2) Write a Python script to get data from API and dump into S3
# * 3) Create a Bucket in S3
# * 4) Create an EC2 instance
# * 6) Create Kinesis Firehose
# * 6) Set up a cron job

# %% [markdown]
# # Step 1: API Credentials

# %% [markdown]
# **API credentials are stored in a .yml file in .ssh:**
#
#     qpx_express_cred.yml

# %% [markdown]
# ### API INFO
#
# **Credentials**:
# <img src="images/qpx_express_cred.png">
#
# There is a free quota of 50 queries per day.

# %% [markdown]
# #### POST Request
#
# standard:
#
#      GET/POST https://www.googleapis.com/apiName/apiVersion/resourcePath?parameters
#
# QPX Express:
#
#      POST https://www.googleapis.com/qpxExpress/v1/trips/search

# %% [markdown]
# #### Resource Path

# %% [markdown]
# * Trips
#
#          POST https://www.googleapis.com/qpxExpress/v1/trips

# %% [markdown]
# #### Request Parameters

# %% [markdown]
# * Overview
#
#          POST https://www.googleapis.com/qpxExpress/v1/trips/overview
#
#
# * Search
#
#          POST https://www.googleapis.com/qpxExpress/v1/trips/search
#
# Returns a list of flights.
#
# ** Search Requests**
#
#
# * slice
#     * "kind": "qpxexpress#sliceInput",
#     * "origin": string,
#     * "destination": string,
#     * "date": string,
#     * "maxStops": integer,
#     * "maxConnectionDuration": integer,
#     * "preferredCabin": string,
#     * "permittedDepartureTime": {
#     * "kind": "qpxexpress#timeOfDayRange",
#     * "earliestTime": string,
#     * "latestTime": string
#
# * passanger
#      * "kind": "qpxexpress#passengerCounts",
#      * "adultCount": integer,
#      * "childCount": integer,
#      * "infantInLapCount": integer,
#      * "infantInSeatCount": integer,
#      * "seniorCount": integer
#      * "alliance": string,
#      * "prohibitedCarrier": string
# * maxPrice: string,
# * saleCountry: string,
# * ticketingCountry: string,
# * refundable: boolean,
# * solutions: integer
#
# More info at: [API Response: JSON schema](https://developers.google.com/qpx-express/v1/trips/search#response)

# %% [markdown]
# #### Json Request Exported from [QPX Express API](https://qpx-express-demo.itasoftware.com)
#
# Json request to QPX API is stored in the file:
#
#     qpx_json_request.json

# %% [markdown]
# #### Pretty Print JSON
#
# [Pretty Print](http://jsonprettyprint.com/)
#
# Returns the json response in a human-readable format

# %% [markdown]
# # Python Script
# The script below make POST requests to the QPX Express API and stores the data in S3 using Kinesis Firehose.
#
#      api_checks.py

# %% [markdown]
# ### Python Script - 1st Test

# %%
#def connect_qpx_express(self, config_filepath='~/.ssh/qpx_express_cred.yml'):  # Stored in .ssh
#    ''' connect to QPX Express, and return a connection
#        INPUT: yaml config filepath
#        OUTPUT: QPX Express object
#    '''

# %%
import json
import requests
import yaml
import pprint
from boto.s3.connection import S3Connection
from boto.s3.key import Key

api_key = "AIzaSyBxO2z1DjQ99WERQCHGApEoi-ccxLpy4eg"

url = "https://www.googleapis.com/qpxExpress/v1/trips/search?key=" + api_key

headers = {'content-type': 'application/json'}

params = {
  "request": {
    "slice": [
      {
        "origin": "SFO",
        "destination": "GRU",
        "date": "2017-07-22"
      },
      {
        "origin": "GRU",
        "destination": "SFO",
        "date": "2017-08-13"
      } 
    ],
    "passengers": {
        "adultCount": 1,
        "infantInLapCount": 0,
        "infantInSeatCount": 0,
        "childCount": 0,
        "seniorCount": 0
    },
    "solutions": 10,
    "refundable": False
  }
}

# Make a post request to QPX Express API by passing endpoint, API key,  params, and headers.
response = requests.post(url, data=json.dumps(params), headers=headers)

# %%
data = response.json()
data
# Out:
# {'kind': 'qpxExpress#tripsSearch',
#  'trips': {'data': {'aircraft': [{'code': '319',
#      'kind': 'qpxexpress#aircraftData',
#      'name': 'Airbus A319'},
#     {'code': '32B',
#      'kind': 'qpxexpress#aircraftData',
#      'name': 'Airbus A321 (Sharklets)'},
#     {'code': '738', 'kind': 'qpxexpress#aircraftData', 'name': 'Boeing 737'},
#     {'code': '773', 'kind': 'qpxexpress#aircraftData', 'name': 'Boeing 777'},
#     {'code': '789', 'kind': 'qpxexpress#aircraftData', 'name': 'Boeing 787'}],
#    'airport': [{'city': 'DFW',
#      'code': 'DFW',
#      'kind': 'qpxexpress#airportData',
#      'name': 'Dallas/Fort Worth International'},
#     {'city': 'SAO',
#      'code': 'GRU',
#      'kind': 'qpxexpress#airportData',
#      'name': 'Sao Paulo Guarulhos International'},
#     {'city': 'MIA',
#      'code': 'MIA',
#      'kind': 'qpxexpress#airportData',
#      'name': 'Miami International'},
#     {'city': 'PTY',
#      'code': 'PTY',
#      'kind': 'qpxexpress#airportData',
#      'name': "Panama City Tocumen Int'l"},
#     {'city': 'SFO',
#      'code': 'SFO',
#      'kind': 'qpxexpress#airportData',
#      'name': 'San Francisco International'}],
#    'carrier': [{'code': 'CM',
#      'kind': 'qpxexpress#carrierData',
#      'name': 'Compania Panamena de Aviacion, S.A.'},
#     {'code': 'JJ',
#      'kind': 'qpxexpress#carrierData',
#      'name': 'LATAM Airlines Brasil'},
#     {'code': 'UA',
#      'kind': 'qpxexpress#carrierData',
#      'name': 'United Airlines, Inc.'}],
#    'city': [{'code': 'DFW',
#      'kind': 'qpxexpress#cityData',
#      'name': 'Dallas/Fort Worth'},
#     {'code': 'MIA', 'kind': 'qpxexpress#cityData', 'name': 'Miami'},
#     {'code': 'PTY', 'kind': 'qpxexpress#cityData', 'name': 'Panama City'},
#     {'code': 'SAO', 'kind': 'qpxexpress#cityData', 'name': 'Sao Paulo'},
#     {'code': 'SFO', 'kind': 'qpxexpress#cityData', 'name': 'San Francisco'}],
#    'kind': 'qpxexpress#data',
#    'tax': [{'id': 'XY',
#      'kind': 'qpxexpress#taxData',
#      'name': 'US Immigration Fee'},
#     {'id': 'AH_003',
#      'kind': 'qpxexpress#taxData',
#      'name': 'Panama Airport Security Fee Departures'},
#     {'id': 'AY_001',
#      'kind': 'qpxexpress#taxData',
#      'name': 'US September 11th Security Fee'},
#     {'id': 'US_002',
#      'kind': 'qpxexpress#taxData',
#      'name': 'US International Departure Tax'},
#     {'id': 'XA', 'kind': 'qpxexpress#taxData', 'name': 'USDA APHIS Fee'},
#     {'id': 'YC', 'kind': 'qpxexpress#taxData', 'name': 'US Customs Fee'},
#     {'id': 'BR_004',
#      'kind': 'qpxexpress#taxData',
#      'name': 'Brazil Embarkation Fee International'},
#     {'id': 'XF',
#      'kind': 'qpxexpress#taxData',
#      'name': 'US Passenger Facility Charge'}]},
#   'kind': 'qpxexpress#tripOptions',
#   'requestId': '9cSc9DcuPpHwaoT1l0QMQx',
#   'tripOption': [{'id': '2V9VinyM98QVgmlHWSF0TC00A',
#     'kind': 'qpxexpress#tripOption',
#     'pricing': [{'baseFareTotal': 'USD1565.00',
#       'fare': [{'basisCode': 'VHWLE99W',
#         'carrier': 'JJ',
#         'destination': 'SAO',
#         'id': 'AfKQZB0+FWBZFL5HGqcsU+4pdRaRXZvQj5dNtm39iuvc',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SFO'},
#        {'basisCode': 'VLWLE99W',
#         'carrier': 'JJ',
#         'destination': 'SFO',
#         'id': 'ACpg/+pitS407BjpA3ldFpGtsbSr20nw4ybS8hivq0SE',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SAO'}],
#       'fareCalculation': 'SFO UA X/DFW JJ SAO Q SFOSAO65.00 M 780.00VHWLE99W JJ X/E/MIA JJ SFO Q SAOSFO65.00 M 655.00VLWLE99W NUC 1565.00 END ROE 1.00 FARE USD 1565.00 XT 5.50YC 7.00XY 3.96XA 36.00US 11.20AY 36.30BR 13.50XF SFO4.50 DFW4.50 MIA4.50',
#       'kind': 'qpxexpress#pricingInfo',
#       'latestTicketingTime': '2017-04-28T23:59-04:00',
#       'passengers': {'adultCount': 1, 'kind': 'qpxexpress#passengerCounts'},
#       'ptc': 'ADT',
#       'refundable': True,
#       'saleFareTotal': 'USD1565.00',
#       'saleTaxTotal': 'USD113.46',
#       'saleTotal': 'USD1678.46',
#       'segmentPricing': [{'fareId': 'AfKQZB0+FWBZFL5HGqcsU+4pdRaRXZvQj5dNtm39iuvc',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GC-Uf2YTDpNa1GcD'},
#        {'fareId': 'AfKQZB0+FWBZFL5HGqcsU+4pdRaRXZvQj5dNtm39iuvc',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GrbbJpsjyHpzg3w4'},
#        {'fareId': 'ACpg/+pitS407BjpA3ldFpGtsbSr20nw4ybS8hivq0SE',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GlEMEKiEBJ6TyzEi'},
#        {'fareId': 'ACpg/+pitS407BjpA3ldFpGtsbSr20nw4ybS8hivq0SE',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GDroDK1znnK2KnD7'}],
#       'tax': [{'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'AY',
#         'country': 'US',
#         'id': 'AY_001',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD11.20'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XF',
#         'country': 'US',
#         'id': 'XF',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD13.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XA',
#         'country': 'US',
#         'id': 'XA',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD3.96'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XY',
#         'country': 'US',
#         'id': 'XY',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD7.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'YC',
#         'country': 'US',
#         'id': 'YC',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'BR',
#         'country': 'BR',
#         'id': 'BR_004',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD36.30'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'}]}],
#     'saleTotal': 'USD1678.46',
#     'slice': [{'duration': 985,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'W',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 155,
#         'duration': 220,
#         'flight': {'carrier': 'UA', 'number': '294'},
#         'id': 'GrbbJpsjyHpzg3w4',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '319',
#           'arrivalTime': '2017-07-22T16:20-05:00',
#           'departureTime': '2017-07-22T10:40-07:00',
#           'destination': 'DFW',
#           'destinationTerminal': 'E',
#           'duration': 220,
#           'id': 'L2MhQ9XkMIg1T+HD',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Food for Purchase',
#           'mileage': 1461,
#           'origin': 'SFO',
#           'originTerminal': '3',
#           'secure': True}],
#         'marriedSegmentGroup': '0'},
#        {'bookingCode': 'V',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 610,
#         'flight': {'carrier': 'JJ', 'number': '8409'},
#         'id': 'GC-Uf2YTDpNa1GcD',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '789',
#           'arrivalTime': '2017-07-23T07:05-03:00',
#           'departureTime': '2017-07-22T18:55-05:00',
#           'destination': 'GRU',
#           'destinationTerminal': '3',
#           'duration': 610,
#           'id': 'LMDhWZ683Uxx7PiO',
#           'kind': 'qpxexpress#legInfo',
#           'mileage': 5120,
#           'operatingDisclosure': 'OPERATED BY AMERICAN',
#           'origin': 'DFW',
#           'originTerminal': 'D',
#           'secure': True}],
#         'marriedSegmentGroup': '1'}]},
#      {'duration': 1056,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'V',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 195,
#         'duration': 500,
#         'flight': {'carrier': 'JJ', 'number': '8094'},
#         'id': 'GlEMEKiEBJ6TyzEi',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '773',
#           'arrivalTime': '2017-08-13T18:20-04:00',
#           'departureTime': '2017-08-13T11:00-03:00',
#           'destination': 'MIA',
#           'duration': 500,
#           'id': 'L6F2l32wCsOkLYHM',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Lunch',
#           'mileage': 4082,
#           'origin': 'GRU',
#           'originTerminal': '3',
#           'secure': True}],
#         'marriedSegmentGroup': '2'},
#        {'bookingCode': 'V',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 361,
#         'flight': {'carrier': 'JJ', 'number': '2038'},
#         'id': 'GDroDK1znnK2KnD7',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '32B',
#           'arrivalTime': '2017-08-14T00:36-07:00',
#           'departureTime': '2017-08-13T21:35-04:00',
#           'destination': 'SFO',
#           'destinationTerminal': '2',
#           'duration': 361,
#           'id': 'LzymoZKjjs90-+1g',
#           'kind': 'qpxexpress#legInfo',
#           'mileage': 2580,
#           'operatingDisclosure': 'OPERATED BY AMERICAN',
#           'origin': 'MIA',
#           'secure': True}],
#         'marriedSegmentGroup': '2'}]}]},
#    {'id': '2V9VinyM98QVgmlHWSF0TC004',
#     'kind': 'qpxexpress#tripOption',
#     'pricing': [{'baseFareTotal': 'USD1620.00',
#       'fare': [{'basisCode': 'D07BC65',
#         'carrier': 'CM',
#         'destination': 'SAO',
#         'id': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SFO'},
#        {'basisCode': 'E28F65',
#         'carrier': 'CM',
#         'destination': 'PTY',
#         'id': 'AhR4W06XMHrF83Yp27G4Eh2pLadQJsh0idzpsq2KAFmo+',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SAO'},
#        {'basisCode': 'EW28A65',
#         'carrier': 'CM',
#         'destination': 'SFO',
#         'id': 'AY312coxya54y8QUa9ZNlzTKAID7eJSvxoJS45ASFI+o',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'PTY'}],
#       'fareCalculation': 'SFO CM X/PTY CM SAO Q SFOSAO65.00 921.00D07BC65 CM X/PTY 390.00E28F65 CM SFO Q80.00 163.50EW28A65 NUC 1619.50 END ROE 1.00 FARE USD 1620.00 XT 5.50YC 7.00XY 3.96XA 36.00US 5.60AY 2.50AH 36.30BR 4.50XF SFO4.50',
#       'kind': 'qpxexpress#pricingInfo',
#       'latestTicketingTime': '2017-04-17T23:59-04:00',
#       'passengers': {'adultCount': 1, 'kind': 'qpxexpress#passengerCounts'},
#       'ptc': 'ADT',
#       'saleFareTotal': 'USD1620.00',
#       'saleTaxTotal': 'USD101.36',
#       'saleTotal': 'USD1721.36',
#       'segmentPricing': [{'fareId': 'AhR4W06XMHrF83Yp27G4Eh2pLadQJsh0idzpsq2KAFmo+',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'Gu4plGliAwCXK3sv'},
#        {'fareId': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'Gz53ITRA+1k4NNiU'},
#        {'fareId': 'AY312coxya54y8QUa9ZNlzTKAID7eJSvxoJS45ASFI+o',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GB6rgm7G5EmUSvka'},
#        {'fareId': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'G0IFD9uSD4SLnSdp'}],
#       'tax': [{'chargeType': 'GOVERNMENT',
#         'code': 'AH',
#         'country': 'PA',
#         'id': 'AH_003',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD2.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'AY',
#         'country': 'US',
#         'id': 'AY_001',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.60'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XF',
#         'country': 'US',
#         'id': 'XF',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD4.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XA',
#         'country': 'US',
#         'id': 'XA',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD3.96'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XY',
#         'country': 'US',
#         'id': 'XY',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD7.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'YC',
#         'country': 'US',
#         'id': 'YC',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'BR',
#         'country': 'BR',
#         'id': 'BR_004',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD36.30'}]}],
#     'saleTotal': 'USD1721.36',
#     'slice': [{'duration': 1150,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'D',
#         'bookingCodeCount': 1,
#         'cabin': 'BUSINESS',
#         'connectionDuration': 291,
#         'duration': 436,
#         'flight': {'carrier': 'CM', 'number': '383'},
#         'id': 'G0IFD9uSD4SLnSdp',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-22T10:51-05:00',
#           'departureTime': '2017-07-22T01:35-07:00',
#           'destination': 'PTY',
#           'duration': 436,
#           'id': 'LhSglxW74Q3etAne',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'SFO',
#           'originTerminal': 'I',
#           'secure': True}],
#         'marriedSegmentGroup': '0'},
#        {'bookingCode': 'D',
#         'bookingCodeCount': 1,
#         'cabin': 'BUSINESS',
#         'duration': 423,
#         'flight': {'carrier': 'CM', 'number': '725'},
#         'id': 'Gz53ITRA+1k4NNiU',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-23T00:45-03:00',
#           'departureTime': '2017-07-22T15:42-05:00',
#           'destination': 'GRU',
#           'destinationTerminal': '2',
#           'duration': 423,
#           'id': 'LQczKZZmut94uIxy',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'PTY'}],
#         'marriedSegmentGroup': '0'}]},
#      {'duration': 968,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'E',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 69,
#         'duration': 428,
#         'flight': {'carrier': 'CM', 'number': '700'},
#         'id': 'Gu4plGliAwCXK3sv',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-08-13T17:08-05:00',
#           'departureTime': '2017-08-13T12:00-03:00',
#           'destination': 'PTY',
#           'duration': 428,
#           'id': 'LOPpomPTcx4-J5fk',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'GRU',
#           'originTerminal': '2'}],
#         'marriedSegmentGroup': '1'},
#        {'bookingCode': 'E',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 471,
#         'flight': {'carrier': 'CM', 'number': '382'},
#         'id': 'GB6rgm7G5EmUSvka',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-08-14T00:08-07:00',
#           'departureTime': '2017-08-13T18:17-05:00',
#           'destination': 'SFO',
#           'destinationTerminal': 'I',
#           'duration': 471,
#           'id': 'LTKCpNrJom13wHsD',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'PTY',
#           'secure': True}],
#         'marriedSegmentGroup': '1'}]}]},
#    {'id': '2V9VinyM98QVgmlHWSF0TC008',
#     'kind': 'qpxexpress#tripOption',
#     'pricing': [{'baseFareTotal': 'USD1620.00',
#       'fare': [{'basisCode': 'D07BC65',
#         'carrier': 'CM',
#         'destination': 'SAO',
#         'id': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SFO'},
#        {'basisCode': 'E28F65',
#         'carrier': 'CM',
#         'destination': 'PTY',
#         'id': 'AhR4W06XMHrF83Yp27G4Eh2pLadQJsh0idzpsq2KAFmo+',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SAO'},
#        {'basisCode': 'EW28A65',
#         'carrier': 'CM',
#         'destination': 'SFO',
#         'id': 'AY312coxya54y8QUa9ZNlzTKAID7eJSvxoJS45ASFI+o',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'PTY'}],
#       'fareCalculation': 'SFO CM X/PTY CM SAO Q SFOSAO65.00 921.00D07BC65 CM X/PTY 390.00E28F65 CM SFO Q80.00 163.50EW28A65 NUC 1619.50 END ROE 1.00 FARE USD 1620.00 XT 5.50YC 7.00XY 3.96XA 36.00US 5.60AY 2.50AH 36.30BR 4.50XF SFO4.50',
#       'kind': 'qpxexpress#pricingInfo',
#       'latestTicketingTime': '2017-04-17T23:59-04:00',
#       'passengers': {'adultCount': 1, 'kind': 'qpxexpress#passengerCounts'},
#       'ptc': 'ADT',
#       'saleFareTotal': 'USD1620.00',
#       'saleTaxTotal': 'USD101.36',
#       'saleTotal': 'USD1721.36',
#       'segmentPricing': [{'fareId': 'AhR4W06XMHrF83Yp27G4Eh2pLadQJsh0idzpsq2KAFmo+',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GhqCj+EdSnCp2db2'},
#        {'fareId': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'G0IFD9uSD4SLnSdp'},
#        {'fareId': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'G2FxRxu2Mk5mQZkE'},
#        {'fareId': 'AY312coxya54y8QUa9ZNlzTKAID7eJSvxoJS45ASFI+o',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'Gq4wEOgpMCzTxAxw'}],
#       'tax': [{'chargeType': 'GOVERNMENT',
#         'code': 'AH',
#         'country': 'PA',
#         'id': 'AH_003',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD2.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'AY',
#         'country': 'US',
#         'id': 'AY_001',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.60'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XF',
#         'country': 'US',
#         'id': 'XF',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD4.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XA',
#         'country': 'US',
#         'id': 'XA',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD3.96'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XY',
#         'country': 'US',
#         'id': 'XY',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD7.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'YC',
#         'country': 'US',
#         'id': 'YC',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'BR',
#         'country': 'BR',
#         'id': 'BR_004',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD36.30'}]}],
#     'saleTotal': 'USD1721.36',
#     'slice': [{'duration': 1135,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'D',
#         'bookingCodeCount': 1,
#         'cabin': 'BUSINESS',
#         'connectionDuration': 273,
#         'duration': 436,
#         'flight': {'carrier': 'CM', 'number': '383'},
#         'id': 'G0IFD9uSD4SLnSdp',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-22T10:51-05:00',
#           'departureTime': '2017-07-22T01:35-07:00',
#           'destination': 'PTY',
#           'duration': 436,
#           'id': 'LhSglxW74Q3etAne',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'SFO',
#           'originTerminal': 'I',
#           'secure': True}],
#         'marriedSegmentGroup': '0'},
#        {'bookingCode': 'D',
#         'bookingCodeCount': 1,
#         'cabin': 'BUSINESS',
#         'duration': 426,
#         'flight': {'carrier': 'CM', 'number': '800'},
#         'id': 'G2FxRxu2Mk5mQZkE',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-23T00:30-03:00',
#           'departureTime': '2017-07-22T15:24-05:00',
#           'destination': 'GRU',
#           'destinationTerminal': '2',
#           'duration': 426,
#           'id': 'LOSVPj9OZyumxM+0',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'PTY'}],
#         'marriedSegmentGroup': '0'}]},
#      {'duration': 965,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'E',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 95,
#         'duration': 419,
#         'flight': {'carrier': 'CM', 'number': '702'},
#         'id': 'GhqCj+EdSnCp2db2',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-08-13T07:59-05:00',
#           'departureTime': '2017-08-13T03:00-03:00',
#           'destination': 'PTY',
#           'duration': 419,
#           'id': 'L5jUhjTfcENcnXpE',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'GRU',
#           'originTerminal': '2'}],
#         'marriedSegmentGroup': '1'},
#        {'bookingCode': 'E',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 451,
#         'flight': {'carrier': 'CM', 'number': '208'},
#         'id': 'Gq4wEOgpMCzTxAxw',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-08-13T15:05-07:00',
#           'departureTime': '2017-08-13T09:34-05:00',
#           'destination': 'SFO',
#           'destinationTerminal': 'I',
#           'duration': 451,
#           'id': 'LyZ+u-9z67RDzqqe',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'PTY',
#           'secure': True}],
#         'marriedSegmentGroup': '1'}]}]},
#    {'id': '2V9VinyM98QVgmlHWSF0TC009',
#     'kind': 'qpxexpress#tripOption',
#     'pricing': [{'baseFareTotal': 'USD1620.00',
#       'fare': [{'basisCode': 'D07BC65',
#         'carrier': 'CM',
#         'destination': 'SAO',
#         'id': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SFO'},
#        {'basisCode': 'E28F65',
#         'carrier': 'CM',
#         'destination': 'PTY',
#         'id': 'AhR4W06XMHrF83Yp27G4Eh2pLadQJsh0idzpsq2KAFmo+',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SAO'},
#        {'basisCode': 'EW28A65',
#         'carrier': 'CM',
#         'destination': 'SFO',
#         'id': 'AY312coxya54y8QUa9ZNlzTKAID7eJSvxoJS45ASFI+o',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'PTY'}],
#       'fareCalculation': 'SFO CM X/PTY CM SAO Q SFOSAO65.00 921.00D07BC65 CM X/PTY 390.00E28F65 CM SFO Q80.00 163.50EW28A65 NUC 1619.50 END ROE 1.00 FARE USD 1620.00 XT 5.50YC 7.00XY 3.96XA 36.00US 5.60AY 2.50AH 36.30BR 4.50XF SFO4.50',
#       'kind': 'qpxexpress#pricingInfo',
#       'latestTicketingTime': '2017-04-17T23:59-04:00',
#       'passengers': {'adultCount': 1, 'kind': 'qpxexpress#passengerCounts'},
#       'ptc': 'ADT',
#       'saleFareTotal': 'USD1620.00',
#       'saleTaxTotal': 'USD101.36',
#       'saleTotal': 'USD1721.36',
#       'segmentPricing': [{'fareId': 'AhR4W06XMHrF83Yp27G4Eh2pLadQJsh0idzpsq2KAFmo+',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GhqCj+EdSnCp2db2'},
#        {'fareId': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'Gz53ITRA+1k4NNiU'},
#        {'fareId': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'G0IFD9uSD4SLnSdp'},
#        {'fareId': 'AY312coxya54y8QUa9ZNlzTKAID7eJSvxoJS45ASFI+o',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'Gq4wEOgpMCzTxAxw'}],
#       'tax': [{'chargeType': 'GOVERNMENT',
#         'code': 'AH',
#         'country': 'PA',
#         'id': 'AH_003',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD2.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'AY',
#         'country': 'US',
#         'id': 'AY_001',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.60'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XF',
#         'country': 'US',
#         'id': 'XF',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD4.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XA',
#         'country': 'US',
#         'id': 'XA',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD3.96'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XY',
#         'country': 'US',
#         'id': 'XY',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD7.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'YC',
#         'country': 'US',
#         'id': 'YC',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'BR',
#         'country': 'BR',
#         'id': 'BR_004',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD36.30'}]}],
#     'saleTotal': 'USD1721.36',
#     'slice': [{'duration': 1150,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'D',
#         'bookingCodeCount': 1,
#         'cabin': 'BUSINESS',
#         'connectionDuration': 291,
#         'duration': 436,
#         'flight': {'carrier': 'CM', 'number': '383'},
#         'id': 'G0IFD9uSD4SLnSdp',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-22T10:51-05:00',
#           'departureTime': '2017-07-22T01:35-07:00',
#           'destination': 'PTY',
#           'duration': 436,
#           'id': 'LhSglxW74Q3etAne',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'SFO',
#           'originTerminal': 'I',
#           'secure': True}],
#         'marriedSegmentGroup': '0'},
#        {'bookingCode': 'D',
#         'bookingCodeCount': 1,
#         'cabin': 'BUSINESS',
#         'duration': 423,
#         'flight': {'carrier': 'CM', 'number': '725'},
#         'id': 'Gz53ITRA+1k4NNiU',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-23T00:45-03:00',
#           'departureTime': '2017-07-22T15:42-05:00',
#           'destination': 'GRU',
#           'destinationTerminal': '2',
#           'duration': 423,
#           'id': 'LQczKZZmut94uIxy',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'PTY'}],
#         'marriedSegmentGroup': '0'}]},
#      {'duration': 965,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'E',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 95,
#         'duration': 419,
#         'flight': {'carrier': 'CM', 'number': '702'},
#         'id': 'GhqCj+EdSnCp2db2',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-08-13T07:59-05:00',
#           'departureTime': '2017-08-13T03:00-03:00',
#           'destination': 'PTY',
#           'duration': 419,
#           'id': 'L5jUhjTfcENcnXpE',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'GRU',
#           'originTerminal': '2'}],
#         'marriedSegmentGroup': '1'},
#        {'bookingCode': 'E',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 451,
#         'flight': {'carrier': 'CM', 'number': '208'},
#         'id': 'Gq4wEOgpMCzTxAxw',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-08-13T15:05-07:00',
#           'departureTime': '2017-08-13T09:34-05:00',
#           'destination': 'SFO',
#           'destinationTerminal': 'I',
#           'duration': 451,
#           'id': 'LyZ+u-9z67RDzqqe',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'PTY',
#           'secure': True}],
#         'marriedSegmentGroup': '1'}]}]},
#    {'id': '2V9VinyM98QVgmlHWSF0TC003',
#     'kind': 'qpxexpress#tripOption',
#     'pricing': [{'baseFareTotal': 'USD1620.00',
#       'fare': [{'basisCode': 'D07BC65',
#         'carrier': 'CM',
#         'destination': 'SAO',
#         'id': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SFO'},
#        {'basisCode': 'E28F65',
#         'carrier': 'CM',
#         'destination': 'PTY',
#         'id': 'AhR4W06XMHrF83Yp27G4Eh2pLadQJsh0idzpsq2KAFmo+',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SAO'},
#        {'basisCode': 'EW28A65',
#         'carrier': 'CM',
#         'destination': 'SFO',
#         'id': 'AY312coxya54y8QUa9ZNlzTKAID7eJSvxoJS45ASFI+o',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'PTY'}],
#       'fareCalculation': 'SFO CM X/PTY CM SAO Q SFOSAO65.00 921.00D07BC65 CM X/PTY 390.00E28F65 CM SFO Q80.00 163.50EW28A65 NUC 1619.50 END ROE 1.00 FARE USD 1620.00 XT 5.50YC 7.00XY 3.96XA 36.00US 5.60AY 2.50AH 36.30BR 4.50XF SFO4.50',
#       'kind': 'qpxexpress#pricingInfo',
#       'latestTicketingTime': '2017-04-17T23:59-04:00',
#       'passengers': {'adultCount': 1, 'kind': 'qpxexpress#passengerCounts'},
#       'ptc': 'ADT',
#       'saleFareTotal': 'USD1620.00',
#       'saleTaxTotal': 'USD101.36',
#       'saleTotal': 'USD1721.36',
#       'segmentPricing': [{'fareId': 'AhR4W06XMHrF83Yp27G4Eh2pLadQJsh0idzpsq2KAFmo+',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'Gu4plGliAwCXK3sv'},
#        {'fareId': 'AY312coxya54y8QUa9ZNlzTKAID7eJSvxoJS45ASFI+o',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GB6rgm7G5EmUSvka'},
#        {'fareId': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'G0IFD9uSD4SLnSdp'},
#        {'fareId': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'G2FxRxu2Mk5mQZkE'}],
#       'tax': [{'chargeType': 'GOVERNMENT',
#         'code': 'AH',
#         'country': 'PA',
#         'id': 'AH_003',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD2.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'AY',
#         'country': 'US',
#         'id': 'AY_001',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.60'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XF',
#         'country': 'US',
#         'id': 'XF',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD4.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XA',
#         'country': 'US',
#         'id': 'XA',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD3.96'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XY',
#         'country': 'US',
#         'id': 'XY',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD7.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'YC',
#         'country': 'US',
#         'id': 'YC',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'BR',
#         'country': 'BR',
#         'id': 'BR_004',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD36.30'}]}],
#     'saleTotal': 'USD1721.36',
#     'slice': [{'duration': 1135,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'D',
#         'bookingCodeCount': 1,
#         'cabin': 'BUSINESS',
#         'connectionDuration': 273,
#         'duration': 436,
#         'flight': {'carrier': 'CM', 'number': '383'},
#         'id': 'G0IFD9uSD4SLnSdp',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-22T10:51-05:00',
#           'departureTime': '2017-07-22T01:35-07:00',
#           'destination': 'PTY',
#           'duration': 436,
#           'id': 'LhSglxW74Q3etAne',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'SFO',
#           'originTerminal': 'I',
#           'secure': True}],
#         'marriedSegmentGroup': '0'},
#        {'bookingCode': 'D',
#         'bookingCodeCount': 1,
#         'cabin': 'BUSINESS',
#         'duration': 426,
#         'flight': {'carrier': 'CM', 'number': '800'},
#         'id': 'G2FxRxu2Mk5mQZkE',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-23T00:30-03:00',
#           'departureTime': '2017-07-22T15:24-05:00',
#           'destination': 'GRU',
#           'destinationTerminal': '2',
#           'duration': 426,
#           'id': 'LOSVPj9OZyumxM+0',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'PTY'}],
#         'marriedSegmentGroup': '0'}]},
#      {'duration': 968,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'E',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 69,
#         'duration': 428,
#         'flight': {'carrier': 'CM', 'number': '700'},
#         'id': 'Gu4plGliAwCXK3sv',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-08-13T17:08-05:00',
#           'departureTime': '2017-08-13T12:00-03:00',
#           'destination': 'PTY',
#           'duration': 428,
#           'id': 'LOPpomPTcx4-J5fk',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'GRU',
#           'originTerminal': '2'}],
#         'marriedSegmentGroup': '1'},
#        {'bookingCode': 'E',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 471,
#         'flight': {'carrier': 'CM', 'number': '382'},
#         'id': 'GB6rgm7G5EmUSvka',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-08-14T00:08-07:00',
#           'departureTime': '2017-08-13T18:17-05:00',
#           'destination': 'SFO',
#           'destinationTerminal': 'I',
#           'duration': 471,
#           'id': 'LTKCpNrJom13wHsD',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'PTY',
#           'secure': True}],
#         'marriedSegmentGroup': '1'}]}]},
#    {'id': '2V9VinyM98QVgmlHWSF0TC006',
#     'kind': 'qpxexpress#tripOption',
#     'pricing': [{'baseFareTotal': 'USD1620.00',
#       'fare': [{'basisCode': 'D07BC65',
#         'carrier': 'CM',
#         'destination': 'SAO',
#         'id': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SFO'},
#        {'basisCode': 'E28F65',
#         'carrier': 'CM',
#         'destination': 'PTY',
#         'id': 'AhR4W06XMHrF83Yp27G4Eh2pLadQJsh0idzpsq2KAFmo+',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SAO'},
#        {'basisCode': 'EW28A65',
#         'carrier': 'CM',
#         'destination': 'SFO',
#         'id': 'AY312coxya54y8QUa9ZNlzTKAID7eJSvxoJS45ASFI+o',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'PTY'}],
#       'fareCalculation': 'SFO CM X/PTY CM SAO Q SFOSAO65.00 921.00D07BC65 CM X/PTY 390.00E28F65 CM SFO Q80.00 163.50EW28A65 NUC 1619.50 END ROE 1.00 FARE USD 1620.00 XT 5.50YC 7.00XY 3.96XA 36.00US 5.60AY 2.50AH 36.30BR 4.50XF SFO4.50',
#       'kind': 'qpxexpress#pricingInfo',
#       'latestTicketingTime': '2017-04-17T23:59-04:00',
#       'passengers': {'adultCount': 1, 'kind': 'qpxexpress#passengerCounts'},
#       'ptc': 'ADT',
#       'saleFareTotal': 'USD1620.00',
#       'saleTaxTotal': 'USD101.36',
#       'saleTotal': 'USD1721.36',
#       'segmentPricing': [{'fareId': 'AhR4W06XMHrF83Yp27G4Eh2pLadQJsh0idzpsq2KAFmo+',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'Gu4plGliAwCXK3sv'},
#        {'fareId': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GaebHWwN5XyhyJ48'},
#        {'fareId': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GD7U1oNWGFdWnysG'},
#        {'fareId': 'AY312coxya54y8QUa9ZNlzTKAID7eJSvxoJS45ASFI+o',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GB6rgm7G5EmUSvka'}],
#       'tax': [{'chargeType': 'GOVERNMENT',
#         'code': 'AH',
#         'country': 'PA',
#         'id': 'AH_003',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD2.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'AY',
#         'country': 'US',
#         'id': 'AY_001',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.60'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XF',
#         'country': 'US',
#         'id': 'XF',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD4.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XA',
#         'country': 'US',
#         'id': 'XA',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD3.96'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XY',
#         'country': 'US',
#         'id': 'XY',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD7.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'YC',
#         'country': 'US',
#         'id': 'YC',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'BR',
#         'country': 'BR',
#         'id': 'BR_004',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD36.30'}]}],
#     'saleTotal': 'USD1721.36',
#     'slice': [{'duration': 1195,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'D',
#         'bookingCodeCount': 6,
#         'cabin': 'BUSINESS',
#         'connectionDuration': 342,
#         'duration': 436,
#         'flight': {'carrier': 'CM', 'number': '209'},
#         'id': 'GD7U1oNWGFdWnysG',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-23T06:06-05:00',
#           'departureTime': '2017-07-22T20:50-07:00',
#           'destination': 'PTY',
#           'duration': 436,
#           'id': 'LX+S38i9fO2rcYDf',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'SFO',
#           'originTerminal': 'I',
#           'secure': True}],
#         'marriedSegmentGroup': '0'},
#        {'bookingCode': 'D',
#         'bookingCodeCount': 6,
#         'cabin': 'BUSINESS',
#         'duration': 417,
#         'flight': {'carrier': 'CM', 'number': '701'},
#         'id': 'GaebHWwN5XyhyJ48',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-23T20:45-03:00',
#           'departureTime': '2017-07-23T11:48-05:00',
#           'destination': 'GRU',
#           'destinationTerminal': '2',
#           'duration': 417,
#           'id': 'LK4dl3ikrtdkPD14',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'PTY'}],
#         'marriedSegmentGroup': '0'}]},
#      {'duration': 968,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'E',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 69,
#         'duration': 428,
#         'flight': {'carrier': 'CM', 'number': '700'},
#         'id': 'Gu4plGliAwCXK3sv',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-08-13T17:08-05:00',
#           'departureTime': '2017-08-13T12:00-03:00',
#           'destination': 'PTY',
#           'duration': 428,
#           'id': 'LOPpomPTcx4-J5fk',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'GRU',
#           'originTerminal': '2'}],
#         'marriedSegmentGroup': '1'},
#        {'bookingCode': 'E',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 471,
#         'flight': {'carrier': 'CM', 'number': '382'},
#         'id': 'GB6rgm7G5EmUSvka',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-08-14T00:08-07:00',
#           'departureTime': '2017-08-13T18:17-05:00',
#           'destination': 'SFO',
#           'destinationTerminal': 'I',
#           'duration': 471,
#           'id': 'LTKCpNrJom13wHsD',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'PTY',
#           'secure': True}],
#         'marriedSegmentGroup': '1'}]}]},
#    {'id': '2V9VinyM98QVgmlHWSF0TC002',
#     'kind': 'qpxexpress#tripOption',
#     'pricing': [{'baseFareTotal': 'USD1659.00',
#       'fare': [{'basisCode': 'KW07S65',
#         'carrier': 'CM',
#         'destination': 'SAO',
#         'id': 'AMtaU+V+0XR9WoC8JVoLVPfH2hSIywZTYgbMo1ouUo/M',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SFO'},
#        {'basisCode': 'E28F65',
#         'carrier': 'CM',
#         'destination': 'PTY',
#         'id': 'AhR4W06XMHrF83Yp27G4Eh2pLadQJsh0idzpsq2KAFmo+',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SAO'},
#        {'basisCode': 'EW28A65',
#         'carrier': 'CM',
#         'destination': 'SFO',
#         'id': 'AY312coxya54y8QUa9ZNlzTKAID7eJSvxoJS45ASFI+o',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'PTY'}],
#       'fareCalculation': 'SFO CM X/PTY CM SAO Q SFOSAO65.00 960.50KW07S65 CM X/PTY 390.00E28F65 CM SFO Q80.00 163.50EW28A65 NUC 1659.00 END ROE 1.00 FARE USD 1659.00 XT 5.50YC 7.00XY 3.96XA 36.00US 5.60AY 2.50AH 36.30BR 4.50XF SFO4.50',
#       'kind': 'qpxexpress#pricingInfo',
#       'latestTicketingTime': '2017-04-17T23:59-04:00',
#       'passengers': {'adultCount': 1, 'kind': 'qpxexpress#passengerCounts'},
#       'ptc': 'ADT',
#       'saleFareTotal': 'USD1659.00',
#       'saleTaxTotal': 'USD101.36',
#       'saleTotal': 'USD1760.36',
#       'segmentPricing': [{'fareId': 'AhR4W06XMHrF83Yp27G4Eh2pLadQJsh0idzpsq2KAFmo+',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GhqCj+EdSnCp2db2'},
#        {'fareId': 'AMtaU+V+0XR9WoC8JVoLVPfH2hSIywZTYgbMo1ouUo/M',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GxdC8mFjEBy4HQWN'},
#        {'fareId': 'AMtaU+V+0XR9WoC8JVoLVPfH2hSIywZTYgbMo1ouUo/M',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'G0IFD9uSD4SLnSdp'},
#        {'fareId': 'AY312coxya54y8QUa9ZNlzTKAID7eJSvxoJS45ASFI+o',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'Gq4wEOgpMCzTxAxw'}],
#       'tax': [{'chargeType': 'GOVERNMENT',
#         'code': 'AH',
#         'country': 'PA',
#         'id': 'AH_003',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD2.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'AY',
#         'country': 'US',
#         'id': 'AY_001',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.60'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XF',
#         'country': 'US',
#         'id': 'XF',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD4.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XA',
#         'country': 'US',
#         'id': 'XA',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD3.96'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XY',
#         'country': 'US',
#         'id': 'XY',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD7.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'YC',
#         'country': 'US',
#         'id': 'YC',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'BR',
#         'country': 'BR',
#         'id': 'BR_004',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD36.30'}]}],
#     'saleTotal': 'USD1760.36',
#     'slice': [{'duration': 910,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'K',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 57,
#         'duration': 436,
#         'flight': {'carrier': 'CM', 'number': '383'},
#         'id': 'G0IFD9uSD4SLnSdp',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-22T10:51-05:00',
#           'departureTime': '2017-07-22T01:35-07:00',
#           'destination': 'PTY',
#           'duration': 436,
#           'id': 'LhSglxW74Q3etAne',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'SFO',
#           'originTerminal': 'I',
#           'secure': True}],
#         'marriedSegmentGroup': '0'},
#        {'bookingCode': 'K',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 417,
#         'flight': {'carrier': 'CM', 'number': '701'},
#         'id': 'GxdC8mFjEBy4HQWN',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-22T20:45-03:00',
#           'departureTime': '2017-07-22T11:48-05:00',
#           'destination': 'GRU',
#           'destinationTerminal': '2',
#           'duration': 417,
#           'id': 'L-LCHrv6WF3kLItR',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'PTY'}],
#         'marriedSegmentGroup': '0'}]},
#      {'duration': 965,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'E',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 95,
#         'duration': 419,
#         'flight': {'carrier': 'CM', 'number': '702'},
#         'id': 'GhqCj+EdSnCp2db2',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-08-13T07:59-05:00',
#           'departureTime': '2017-08-13T03:00-03:00',
#           'destination': 'PTY',
#           'duration': 419,
#           'id': 'L5jUhjTfcENcnXpE',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'GRU',
#           'originTerminal': '2'}],
#         'marriedSegmentGroup': '1'},
#        {'bookingCode': 'E',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 451,
#         'flight': {'carrier': 'CM', 'number': '208'},
#         'id': 'Gq4wEOgpMCzTxAxw',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-08-13T15:05-07:00',
#           'departureTime': '2017-08-13T09:34-05:00',
# ...
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'K',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 57,
#         'duration': 436,
#         'flight': {'carrier': 'CM', 'number': '383'},
#         'id': 'G0IFD9uSD4SLnSdp',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-22T10:51-05:00',
#           'departureTime': '2017-07-22T01:35-07:00',
#           'destination': 'PTY',
#           'duration': 436,
#           'id': 'LhSglxW74Q3etAne',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'SFO',
#           'originTerminal': 'I',
#           'secure': True}],
#         'marriedSegmentGroup': '0'},
#        {'bookingCode': 'K',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 417,
#         'flight': {'carrier': 'CM', 'number': '701'},
#         'id': 'GxdC8mFjEBy4HQWN',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-22T20:45-03:00',
#           'departureTime': '2017-07-22T11:48-05:00',
#           'destination': 'GRU',
#           'destinationTerminal': '2',
#           'duration': 417,
#           'id': 'L-LCHrv6WF3kLItR',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'PTY'}],
#         'marriedSegmentGroup': '0'}]},
#      {'duration': 968,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'E',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 69,
#         'duration': 428,
#         'flight': {'carrier': 'CM', 'number': '700'},
#         'id': 'Gu4plGliAwCXK3sv',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-08-13T17:08-05:00',
#           'departureTime': '2017-08-13T12:00-03:00',
#           'destination': 'PTY',
#           'duration': 428,
#           'id': 'LOPpomPTcx4-J5fk',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'GRU',
#           'originTerminal': '2'}],
#         'marriedSegmentGroup': '1'},
#        {'bookingCode': 'E',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 471,
#         'flight': {'carrier': 'CM', 'number': '382'},
#         'id': 'GB6rgm7G5EmUSvka',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-08-14T00:08-07:00',
#           'departureTime': '2017-08-13T18:17-05:00',
#           'destination': 'SFO',
#           'destinationTerminal': 'I',
#           'duration': 471,
#           'id': 'LTKCpNrJom13wHsD',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'PTY',
#           'secure': True}],
#         'marriedSegmentGroup': '1'}]}]},
#    {'id': '2V9VinyM98QVgmlHWSF0TC007',
#     'kind': 'qpxexpress#tripOption',
#     'pricing': [{'baseFareTotal': 'USD1659.00',
#       'fare': [{'basisCode': 'KW07S65',
#         'carrier': 'CM',
#         'destination': 'SAO',
#         'id': 'AMtaU+V+0XR9WoC8JVoLVPfH2hSIywZTYgbMo1ouUo/M',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SFO'},
#        {'basisCode': 'E28F65',
#         'carrier': 'CM',
#         'destination': 'PTY',
#         'id': 'AhR4W06XMHrF83Yp27G4Eh2pLadQJsh0idzpsq2KAFmo+',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SAO'},
#        {'basisCode': 'EW28A65',
#         'carrier': 'CM',
#         'destination': 'SFO',
#         'id': 'AY312coxya54y8QUa9ZNlzTKAID7eJSvxoJS45ASFI+o',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'PTY'}],
#       'fareCalculation': 'SFO CM X/PTY CM SAO Q SFOSAO65.00 960.50KW07S65 CM X/PTY 390.00E28F65 CM SFO Q80.00 163.50EW28A65 NUC 1659.00 END ROE 1.00 FARE USD 1659.00 XT 5.50YC 7.00XY 3.96XA 36.00US 5.60AY 2.50AH 36.30BR 4.50XF SFO4.50',
#       'kind': 'qpxexpress#pricingInfo',
#       'latestTicketingTime': '2017-04-17T23:59-04:00',
#       'passengers': {'adultCount': 1, 'kind': 'qpxexpress#passengerCounts'},
#       'ptc': 'ADT',
#       'saleFareTotal': 'USD1659.00',
#       'saleTaxTotal': 'USD101.36',
#       'saleTotal': 'USD1760.36',
#       'segmentPricing': [{'fareId': 'AMtaU+V+0XR9WoC8JVoLVPfH2hSIywZTYgbMo1ouUo/M',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GxdC8mFjEBy4HQWN'},
#        {'fareId': 'AhR4W06XMHrF83Yp27G4Eh2pLadQJsh0idzpsq2KAFmo+',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GEIH5LQIMk7YrTyl'},
#        {'fareId': 'AMtaU+V+0XR9WoC8JVoLVPfH2hSIywZTYgbMo1ouUo/M',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'G0IFD9uSD4SLnSdp'},
#        {'fareId': 'AY312coxya54y8QUa9ZNlzTKAID7eJSvxoJS45ASFI+o',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'Gq4wEOgpMCzTxAxw'}],
#       'tax': [{'chargeType': 'GOVERNMENT',
#         'code': 'AH',
#         'country': 'PA',
#         'id': 'AH_003',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD2.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'AY',
#         'country': 'US',
#         'id': 'AY_001',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.60'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XF',
#         'country': 'US',
#         'id': 'XF',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD4.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XA',
#         'country': 'US',
#         'id': 'XA',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD3.96'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XY',
#         'country': 'US',
#         'id': 'XY',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD7.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'YC',
#         'country': 'US',
#         'id': 'YC',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'BR',
#         'country': 'BR',
#         'id': 'BR_004',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD36.30'}]}],
#     'saleTotal': 'USD1760.36',
#     'slice': [{'duration': 910,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'K',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 57,
#         'duration': 436,
#         'flight': {'carrier': 'CM', 'number': '383'},
#         'id': 'G0IFD9uSD4SLnSdp',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-22T10:51-05:00',
#           'departureTime': '2017-07-22T01:35-07:00',
#           'destination': 'PTY',
#           'duration': 436,
#           'id': 'LhSglxW74Q3etAne',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'SFO',
#           'originTerminal': 'I',
#           'secure': True}],
#         'marriedSegmentGroup': '0'},
#        {'bookingCode': 'K',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 417,
#         'flight': {'carrier': 'CM', 'number': '701'},
#         'id': 'GxdC8mFjEBy4HQWN',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-22T20:45-03:00',
#           'departureTime': '2017-07-22T11:48-05:00',
#           'destination': 'GRU',
#           'destinationTerminal': '2',
#           'duration': 417,
#           'id': 'L-LCHrv6WF3kLItR',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'PTY'}],
#         'marriedSegmentGroup': '0'}]},
#      {'duration': 1075,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'E',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 205,
#         'duration': 419,
#         'flight': {'carrier': 'CM', 'number': '758'},
#         'id': 'GEIH5LQIMk7YrTyl',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-08-13T06:09-05:00',
#           'departureTime': '2017-08-13T01:10-03:00',
#           'destination': 'PTY',
#           'duration': 419,
#           'id': 'LiWfo5k59-++Q1Tl',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'GRU',
#           'originTerminal': '2'}],
#         'marriedSegmentGroup': '1'},
#        {'bookingCode': 'E',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 451,
#         'flight': {'carrier': 'CM', 'number': '208'},
#         'id': 'Gq4wEOgpMCzTxAxw',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-08-13T15:05-07:00',
#           'departureTime': '2017-08-13T09:34-05:00',
#           'destination': 'SFO',
#           'destinationTerminal': 'I',
#           'duration': 451,
#           'id': 'LyZ+u-9z67RDzqqe',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'PTY',
#           'secure': True}],
#         'marriedSegmentGroup': '1'}]}]},
#    {'id': '2V9VinyM98QVgmlHWSF0TC005',
#     'kind': 'qpxexpress#tripOption',
#     'pricing': [{'baseFareTotal': 'USD1659.00',
#       'fare': [{'basisCode': 'KW07S65',
#         'carrier': 'CM',
#         'destination': 'SAO',
#         'id': 'AMtaU+V+0XR9WoC8JVoLVPfH2hSIywZTYgbMo1ouUo/M',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SFO'},
#        {'basisCode': 'E28F65',
#         'carrier': 'CM',
#         'destination': 'PTY',
#         'id': 'AhR4W06XMHrF83Yp27G4Eh2pLadQJsh0idzpsq2KAFmo+',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SAO'},
#        {'basisCode': 'EW28A65',
#         'carrier': 'CM',
#         'destination': 'SFO',
#         'id': 'AY312coxya54y8QUa9ZNlzTKAID7eJSvxoJS45ASFI+o',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'PTY'}],
#       'fareCalculation': 'SFO CM X/PTY CM SAO Q SFOSAO65.00 960.50KW07S65 CM X/PTY 390.00E28F65 CM SFO Q80.00 163.50EW28A65 NUC 1659.00 END ROE 1.00 FARE USD 1659.00 XT 5.50YC 7.00XY 3.96XA 36.00US 5.60AY 2.50AH 36.30BR 4.50XF SFO4.50',
#       'kind': 'qpxexpress#pricingInfo',
#       'latestTicketingTime': '2017-04-17T23:59-04:00',
#       'passengers': {'adultCount': 1, 'kind': 'qpxexpress#passengerCounts'},
#       'ptc': 'ADT',
#       'saleFareTotal': 'USD1659.00',
#       'saleTaxTotal': 'USD101.36',
#       'saleTotal': 'USD1760.36',
#       'segmentPricing': [{'fareId': 'AMtaU+V+0XR9WoC8JVoLVPfH2hSIywZTYgbMo1ouUo/M',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GxdC8mFjEBy4HQWN'},
#        {'fareId': 'AMtaU+V+0XR9WoC8JVoLVPfH2hSIywZTYgbMo1ouUo/M',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'G0IFD9uSD4SLnSdp'},
#        {'fareId': 'AhR4W06XMHrF83Yp27G4Eh2pLadQJsh0idzpsq2KAFmo+',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GrLO3X0mh8rY8DVZ'},
#        {'fareId': 'AY312coxya54y8QUa9ZNlzTKAID7eJSvxoJS45ASFI+o',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'Gq4wEOgpMCzTxAxw'}],
#       'tax': [{'chargeType': 'GOVERNMENT',
#         'code': 'AH',
#         'country': 'PA',
#         'id': 'AH_003',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD2.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'AY',
#         'country': 'US',
#         'id': 'AY_001',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.60'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XF',
#         'country': 'US',
#         'id': 'XF',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD4.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XA',
#         'country': 'US',
#         'id': 'XA',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD3.96'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XY',
#         'country': 'US',
#         'id': 'XY',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD7.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'YC',
#         'country': 'US',
#         'id': 'YC',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'BR',
#         'country': 'BR',
#         'id': 'BR_004',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD36.30'}]}],
#     'saleTotal': 'USD1760.36',
#     'slice': [{'duration': 910,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'K',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 57,
#         'duration': 436,
#         'flight': {'carrier': 'CM', 'number': '383'},
#         'id': 'G0IFD9uSD4SLnSdp',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-22T10:51-05:00',
#           'departureTime': '2017-07-22T01:35-07:00',
#           'destination': 'PTY',
#           'duration': 436,
#           'id': 'LhSglxW74Q3etAne',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'SFO',
#           'originTerminal': 'I',
#           'secure': True}],
#         'marriedSegmentGroup': '0'},
#        {'bookingCode': 'K',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 417,
#         'flight': {'carrier': 'CM', 'number': '701'},
#         'id': 'GxdC8mFjEBy4HQWN',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-22T20:45-03:00',
#           'departureTime': '2017-07-22T11:48-05:00',
#           'destination': 'GRU',
#           'destinationTerminal': '2',
#           'duration': 417,
#           'id': 'L-LCHrv6WF3kLItR',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'PTY'}],
#         'marriedSegmentGroup': '0'}]},
#      {'duration': 1055,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'E',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 190,
#         'duration': 414,
#         'flight': {'carrier': 'CM', 'number': '801'},
#         'id': 'GrLO3X0mh8rY8DVZ',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-08-13T06:24-05:00',
#           'departureTime': '2017-08-13T01:30-03:00',
#           'destination': 'PTY',
#           'duration': 414,
#           'id': 'Lg1DC6TqFRRrO97I',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'GRU',
#           'originTerminal': '2'}],
#         'marriedSegmentGroup': '1'},
#        {'bookingCode': 'E',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 451,
#         'flight': {'carrier': 'CM', 'number': '208'},
#         'id': 'Gq4wEOgpMCzTxAxw',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-08-13T15:05-07:00',
#           'departureTime': '2017-08-13T09:34-05:00',
#           'destination': 'SFO',
#           'destinationTerminal': 'I',
#           'duration': 451,
#           'id': 'LyZ+u-9z67RDzqqe',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'PTY',
#           'secure': True}],
#         'marriedSegmentGroup': '1'}]}]}]}}

# %%
# Http response Headers is a dictionary
response.headers
# Out:
# {'Date': 'Thu, 13 Apr 2017 08:48:31 GMT', 'ETag': '"1syu42EjUdK2xe3y0r4xzvGJtSA/8NxRmUmRignTGx3J8VIUdObEAmA"', 'Pragma': 'no-cache', 'X-Content-Type-Options': 'nosniff', 'Alt-Svc': 'quic=":443"; ma=2592000; v="37,36,35"', 'Expires': 'Mon, 01 Jan 1990 00:00:00 GMT', 'X-Frame-Options': 'SAMEORIGIN', 'Server': 'GSE', 'X-XSS-Protection': '1; mode=block', 'Transfer-Encoding': 'chunked', 'Content-Type': 'application/json; charset=UTF-8', 'Vary': 'Origin, X-Origin', 'Content-Encoding': 'gzip', 'Cache-Control': 'no-cache, no-store, max-age=0, must-revalidate'}

# %%
# Get the content-type from the dictionary.
response.headers["content-type"]
# Out:
# 'application/json; charset=UTF-8'

# %%
import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#                               kind  \
# data        qpxExpress#tripsSearch
# kind        qpxExpress#tripsSearch
# requestId   qpxExpress#tripsSearch
# tripOption  qpxExpress#tripsSearch
#
#                                                         trips
# data        {'airport': [{'city': 'DFW', 'code': 'DFW', 'k...
# kind                                   qpxexpress#tripOptions
# requestId                              JA9ztPVeoTqnR6Xsi0QLk1
# tripOption  [{'slice': [{'duration': 985, 'kind': 'qpxexpr...

# %% [markdown]
# # Step 3: Create Bucket in S3 to load API data

# %% [markdown]
#    Bucket was created using AWS console. The bucket is called "qpxexpress".
#
#    <img src="images/S3_bucket.png">

# %% [markdown]
# # Step 4: Create an EC2 instance
#
# **SSH into EC2 instance**
#
#     ssh -i ~/.ssh/MyKeyPair.pem ec2-user@ec2-54-209-30-187.compute-1.amazonaws.com

# %% [markdown]
# #### Transfer Python Scrit File from local computer to EC2
#      scp -i ~/.ssh/file.pem api_checks.py ec2-user@ec2-54-209-30-187.compute-1.amazonaws.com

# %% [markdown]
# # Step 5: Create Firehose Stream

# %% [markdown]
# Use boto3 to connect Kinesis Firehose to connect to API and dump data into S3

# %% [markdown]
# # Step 6: Create a cron job
#
# Set up a cronjob to run every 30 minutes.
#
#    * ssh into EC2
#    * run cron job
#         * crontab -e

# %%
*/30 * * * * python3 api_checks.py

# %% [markdown]
# ### Get notified in case cronjob fail
# <img src="images/cronjob_email_notification.png">
# <img src="images/cron_mail.png">
#
#
# [Helpful Cron tips](https://www.liquidweb.com/kb/how-to-display-list-all-jobs-in-cron-crontab/)

# %%
import json
import requests
import yaml
import pprint
from boto.s3.connection import S3Connection
from boto.s3.key import Key

api_key = "AIzaSyBxO2z1DjQ99WERQCHGApEoi-ccxLpy4eg"

url = "https://www.googleapis.com/qpxExpress/v1/trips/search?key=" + api_key

headers = {'content-type': 'application/json'}

date_of_travel = ["2017-07-01","2017-07-02","2017-07-03","2017-07-04","2017-07-05","2017-07-06"
"2017-07-07","2017-07-08","2017-07-09","2017-07-10","2017-07-11","2017-07-12","2017-07-13",
"2017-07-14","2017-07-15","2017-07-16","2017-07-17", "2017-07-18","2017-07-19",
"2017-07-20","2017-07-21","2017-07-22","2017-07-23","2017-07-24","2017-07-25","2017-07-26",
"2017-07-27", "2017-07-28","2017-07-29","2017-07-30","2017-07-31"]

params = {
  "request": {
    "slice": [
      {
        "origin": "SFO",
        "destination": "GRU",
        "date": date_of_travel
      },
      {
        "origin": "GRU",
        "destination": "SFO",
        "date": date_of_travel
      } 
    ],
    "passengers": {
        "adultCount": 1,
        "infantInLapCount": 0,
        "infantInSeatCount": 0,
        "childCount": 0,
        "seniorCount": 0
    },
    "solutions": 10,
    "refundable": False
  }
}

# Make a post request to QPX Express API by passing endpoint, API key,  params, and headers.
response = requests.post(url, data=json.dumps(params), headers=headers)

# %%
data = response.json()
data
# Out:
# {'kind': 'qpxExpress#tripsSearch',
#  'trips': {'data': {'aircraft': [{'code': '738',
#      'kind': 'qpxexpress#aircraftData',
#      'name': 'Boeing 737'},
#     {'code': '753', 'kind': 'qpxexpress#aircraftData', 'name': 'Boeing 757'},
#     {'code': '777', 'kind': 'qpxexpress#aircraftData', 'name': 'Boeing 777'}],
#    'airport': [{'city': 'SAO',
#      'code': 'GRU',
#      'kind': 'qpxexpress#airportData',
#      'name': 'Sao Paulo Guarulhos International'},
#     {'city': 'MEX',
#      'code': 'MEX',
#      'kind': 'qpxexpress#airportData',
#      'name': 'Mexico City Benito Juarez International'},
#     {'city': 'CHI',
#      'code': 'ORD',
#      'kind': 'qpxexpress#airportData',
#      'name': "Chicago O'Hare"},
#     {'city': 'PTY',
#      'code': 'PTY',
#      'kind': 'qpxexpress#airportData',
#      'name': "Panama City Tocumen Int'l"},
#     {'city': 'SFO',
#      'code': 'SFO',
#      'kind': 'qpxexpress#airportData',
#      'name': 'San Francisco International'}],
#    'carrier': [{'code': 'AD',
#      'kind': 'qpxexpress#carrierData',
#      'name': 'Azul Linhas Aereas Brasileiras'},
#     {'code': 'AM', 'kind': 'qpxexpress#carrierData', 'name': 'Aeromexico'},
#     {'code': 'CM',
#      'kind': 'qpxexpress#carrierData',
#      'name': 'Compania Panamena de Aviacion, S.A.'},
#     {'code': 'UA',
#      'kind': 'qpxexpress#carrierData',
#      'name': 'United Airlines, Inc.'}],
#    'city': [{'code': 'CHI', 'kind': 'qpxexpress#cityData', 'name': 'Chicago'},
#     {'code': 'MEX', 'kind': 'qpxexpress#cityData', 'name': 'Mexico City'},
#     {'code': 'PTY', 'kind': 'qpxexpress#cityData', 'name': 'Panama City'},
#     {'code': 'SAO', 'kind': 'qpxexpress#cityData', 'name': 'Sao Paulo'},
#     {'code': 'SFO', 'kind': 'qpxexpress#cityData', 'name': 'San Francisco'}],
#    'kind': 'qpxexpress#data',
#    'tax': [{'id': 'XY',
#      'kind': 'qpxexpress#taxData',
#      'name': 'US Immigration Fee'},
#     {'id': 'AH_003',
#      'kind': 'qpxexpress#taxData',
#      'name': 'Panama Airport Security Fee Departures'},
#     {'id': 'AY_001',
#      'kind': 'qpxexpress#taxData',
#      'name': 'US September 11th Security Fee'},
#     {'id': 'US_002',
#      'kind': 'qpxexpress#taxData',
#      'name': 'US International Departure Tax'},
#     {'id': 'XA', 'kind': 'qpxexpress#taxData', 'name': 'USDA APHIS Fee'},
#     {'id': 'YC', 'kind': 'qpxexpress#taxData', 'name': 'US Customs Fee'},
#     {'id': 'YR_I', 'kind': 'qpxexpress#taxData', 'name': 'AM YR surcharge'},
#     {'id': 'BR_004',
#      'kind': 'qpxexpress#taxData',
#      'name': 'Brazil Embarkation Fee International'},
#     {'id': 'XF',
#      'kind': 'qpxexpress#taxData',
#      'name': 'US Passenger Facility Charge'}]},
#   'kind': 'qpxexpress#tripOptions',
#   'requestId': 'EUKmvoZX2tXhI6gnn0QVLg',
#   'tripOption': [{'id': '1oWFUYz0DUSTGDeBQG7yX4001',
#     'kind': 'qpxexpress#tripOption',
#     'pricing': [{'baseFareTotal': 'USD2511.00',
#       'fare': [{'basisCode': 'D07BC65',
#         'carrier': 'CM',
#         'destination': 'SAO',
#         'id': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SFO'},
#        {'basisCode': 'LRHWSL',
#         'carrier': 'AM',
#         'destination': 'MEX',
#         'id': 'ABgNdfEIwn41DDQgdPKH46iBM+vVrHwzTNAsJaxXI3DY2',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SAO'},
#        {'basisCode': 'HOHSL',
#         'carrier': 'AM',
#         'destination': 'SFO',
#         'id': 'ARi5ZIgCnFOr+iR0x9Is/5oNGJ3P0ZR8RPI8p8Tn+UMI',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'MEX'}],
#       'fareCalculation': 'SFO CM X/PTY CM SAO Q SFOSAO65.00 921.00D07BC65 AM X/MEX 1085.00LRHWSL AM SFO Q15.00 425.00HOHSL NUC 2511.00 END ROE 1.00 FARE USD 2511.00 XT 5.50YC 7.00XY 3.96XA 36.00US 5.60AY 1.25AH 35.70BR 0.80YR 4.50XF SFO4.50',
#       'kind': 'qpxexpress#pricingInfo',
#       'latestTicketingTime': '2017-05-11T23:59-04:00',
#       'passengers': {'adultCount': 1, 'kind': 'qpxexpress#passengerCounts'},
#       'ptc': 'ADT',
#       'saleFareTotal': 'USD2511.00',
#       'saleTaxTotal': 'USD100.31',
#       'saleTotal': 'USD2611.31',
#       'segmentPricing': [{'fareId': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'G9Tkq01pWC+Vi+Iq'},
#        {'fareId': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'Gu5+lk0U0JH-9Ruh'},
#        {'fareId': 'ARi5ZIgCnFOr+iR0x9Is/5oNGJ3P0ZR8RPI8p8Tn+UMI',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GDH5sayKezFfIdO1'},
#        {'fareId': 'ABgNdfEIwn41DDQgdPKH46iBM+vVrHwzTNAsJaxXI3DY2',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GJDMgR6PqK2ZsijP'}],
#       'tax': [{'chargeType': 'GOVERNMENT',
#         'code': 'AH',
#         'country': 'PA',
#         'id': 'AH_003',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD1.25'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'AY',
#         'country': 'US',
#         'id': 'AY_001',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.60'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XF',
#         'country': 'US',
#         'id': 'XF',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD4.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XA',
#         'country': 'US',
#         'id': 'XA',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD3.96'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XY',
#         'country': 'US',
#         'id': 'XY',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD7.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'YC',
#         'country': 'US',
#         'id': 'YC',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'CARRIER_SURCHARGE',
#         'code': 'YR',
#         'id': 'YR_I',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD0.80'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'BR',
#         'country': 'BR',
#         'id': 'BR_004',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD35.70'}]}],
#     'saleTotal': 'USD2611.31',
#     'slice': [{'duration': 910,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'D',
#         'bookingCodeCount': 1,
#         'cabin': 'BUSINESS',
#         'connectionDuration': 40,
#         'duration': 441,
#         'flight': {'carrier': 'CM', 'number': '383'},
#         'id': 'Gu5+lk0U0JH-9Ruh',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-01T10:56-05:00',
#           'departureTime': '2017-07-01T01:35-07:00',
#           'destination': 'PTY',
#           'duration': 441,
#           'id': 'LYJ-eyeuBjnF9EN3',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'SFO',
#           'originTerminal': 'I',
#           'secure': True}],
#         'marriedSegmentGroup': '0'},
#        {'bookingCode': 'D',
#         'bookingCodeCount': 1,
#         'cabin': 'BUSINESS',
#         'duration': 429,
#         'flight': {'carrier': 'CM', 'number': '701'},
#         'id': 'G9Tkq01pWC+Vi+Iq',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-01T20:45-03:00',
#           'departureTime': '2017-07-01T11:36-05:00',
#           'destination': 'GRU',
#           'destinationTerminal': '2',
#           'duration': 429,
#           'id': 'LliOmCE6VgyW31yi',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'PTY'}],
#         'marriedSegmentGroup': '0'}]},
#      {'duration': 1030,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'L',
#         'bookingCodeCount': 2,
#         'cabin': 'COACH',
#         'connectionDuration': 132,
#         'duration': 610,
#         'flight': {'carrier': 'AM', 'number': '15'},
#         'id': 'GJDMgR6PqK2ZsijP',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '777',
#           'arrivalTime': '2017-07-02T07:05-05:00',
#           'departureTime': '2017-07-01T22:55-03:00',
#           'destination': 'MEX',
#           'destinationTerminal': '2',
#           'duration': 610,
#           'id': 'LKuBVYWoO9eRatQU',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Alcoholic Beverages - Complimentary',
#           'mileage': 4616,
#           'origin': 'GRU',
#           'originTerminal': '2'}],
#         'marriedSegmentGroup': '1'},
#        {'bookingCode': 'H',
#         'bookingCodeCount': 7,
#         'cabin': 'COACH',
#         'duration': 288,
#         'flight': {'carrier': 'AM', 'number': '668'},
#         'id': 'GDH5sayKezFfIdO1',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-02T12:05-07:00',
#           'departureTime': '2017-07-02T09:17-05:00',
#           'destination': 'SFO',
#           'destinationTerminal': 'I',
#           'duration': 288,
#           'id': 'LKGJABK3JIvDqmPf',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Breakfast',
#           'mileage': 1881,
#           'origin': 'MEX',
#           'originTerminal': '2',
#           'secure': True}],
#         'marriedSegmentGroup': '2'}]}]},
#    {'id': '1oWFUYz0DUSTGDeBQG7yX4002',
#     'kind': 'qpxexpress#tripOption',
#     'pricing': [{'baseFareTotal': 'USD3001.00',
#       'fare': [{'basisCode': 'D07BC65',
#         'carrier': 'CM',
#         'destination': 'SAO',
#         'id': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SFO'},
#        {'basisCode': 'LRHWSL',
#         'carrier': 'AM',
#         'destination': 'MEX',
#         'id': 'ABgNdfEIwn41DDQgdPKH46iBM+vVrHwzTNAsJaxXI3DY2',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SAO'},
#        {'basisCode': 'BNA0A9EY',
#         'carrier': 'UA',
#         'destination': 'SFO',
#         'id': 'A+she8m61i/b+1eEzZlYV6d9n5ASWDgHZQPF/Ikdut5/',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'MEX'}],
#       'fareCalculation': 'SFO CM X/PTY CM SAO Q SFOSAO65.00 921.00D07BC65 AM X/MEX 1085.00LRHWSL UA SFO 930.00BNA0A9EY NUC 3001.00 END ROE 1.00 FARE USD 3001.00 XT 5.50YC 7.00XY 3.96XA 36.00US 5.60AY 1.25AH 35.70BR 4.50XF SFO4.50',
#       'kind': 'qpxexpress#pricingInfo',
#       'latestTicketingTime': '2017-05-11T23:59-04:00',
#       'passengers': {'adultCount': 1, 'kind': 'qpxexpress#passengerCounts'},
#       'ptc': 'ADT',
#       'refundable': True,
#       'saleFareTotal': 'USD3001.00',
#       'saleTaxTotal': 'USD99.51',
#       'saleTotal': 'USD3100.51',
#       'segmentPricing': [{'fareId': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'G9Tkq01pWC+Vi+Iq'},
#        {'fareId': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'Gu5+lk0U0JH-9Ruh'},
#        {'fareId': 'A+she8m61i/b+1eEzZlYV6d9n5ASWDgHZQPF/Ikdut5/',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GAI1fjvWCfxc+lVR'},
#        {'fareId': 'ABgNdfEIwn41DDQgdPKH46iBM+vVrHwzTNAsJaxXI3DY2',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GJDMgR6PqK2ZsijP'}],
#       'tax': [{'chargeType': 'GOVERNMENT',
#         'code': 'AH',
#         'country': 'PA',
#         'id': 'AH_003',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD1.25'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'AY',
#         'country': 'US',
#         'id': 'AY_001',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.60'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XF',
#         'country': 'US',
#         'id': 'XF',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD4.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XA',
#         'country': 'US',
#         'id': 'XA',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD3.96'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XY',
#         'country': 'US',
#         'id': 'XY',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD7.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'YC',
#         'country': 'US',
#         'id': 'YC',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'BR',
#         'country': 'BR',
#         'id': 'BR_004',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD35.70'}]}],
#     'saleTotal': 'USD3100.51',
#     'slice': [{'duration': 910,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'D',
#         'bookingCodeCount': 1,
#         'cabin': 'BUSINESS',
#         'connectionDuration': 40,
#         'duration': 441,
#         'flight': {'carrier': 'CM', 'number': '383'},
#         'id': 'Gu5+lk0U0JH-9Ruh',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-01T10:56-05:00',
#           'departureTime': '2017-07-01T01:35-07:00',
#           'destination': 'PTY',
#           'duration': 441,
#           'id': 'LYJ-eyeuBjnF9EN3',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'SFO',
#           'originTerminal': 'I',
#           'secure': True}],
#         'marriedSegmentGroup': '0'},
#        {'bookingCode': 'D',
#         'bookingCodeCount': 1,
#         'cabin': 'BUSINESS',
#         'duration': 429,
#         'flight': {'carrier': 'CM', 'number': '701'},
#         'id': 'G9Tkq01pWC+Vi+Iq',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-01T20:45-03:00',
#           'departureTime': '2017-07-01T11:36-05:00',
#           'destination': 'GRU',
#           'destinationTerminal': '2',
#           'duration': 429,
#           'id': 'LliOmCE6VgyW31yi',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'PTY'}],
#         'marriedSegmentGroup': '0'}]},
#      {'duration': 1295,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'L',
#         'bookingCodeCount': 2,
#         'cabin': 'COACH',
#         'connectionDuration': 395,
#         'duration': 610,
#         'flight': {'carrier': 'AM', 'number': '15'},
#         'id': 'GJDMgR6PqK2ZsijP',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '777',
#           'arrivalTime': '2017-07-02T07:05-05:00',
#           'departureTime': '2017-07-01T22:55-03:00',
#           'destination': 'MEX',
#           'destinationTerminal': '2',
#           'duration': 610,
#           'id': 'LKuBVYWoO9eRatQU',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Alcoholic Beverages - Complimentary',
#           'mileage': 4616,
#           'origin': 'GRU',
#           'originTerminal': '2'}],
#         'marriedSegmentGroup': '1'},
#        {'bookingCode': 'B',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 290,
#         'flight': {'carrier': 'UA', 'number': '718'},
#         'id': 'GAI1fjvWCfxc+lVR',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-02T16:30-07:00',
#           'departureTime': '2017-07-02T13:40-05:00',
#           'destination': 'SFO',
#           'destinationTerminal': 'I',
#           'duration': 290,
#           'id': 'L+Q9LVaYyOTSS+1F',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Food for Purchase',
#           'mileage': 1881,
#           'origin': 'MEX',
#           'originTerminal': '1',
#           'secure': True}],
#         'marriedSegmentGroup': '2'}]}]},
#    {'id': '1oWFUYz0DUSTGDeBQG7yX4003',
#     'kind': 'qpxexpress#tripOption',
#     'pricing': [{'baseFareTotal': 'USD3028.00',
#       'fare': [{'basisCode': 'QWERT65',
#         'carrier': 'CM',
#         'destination': 'PTY',
#         'id': 'A4Lag1ANi41XiQkx+LwWQsN3mFR7Zd8R8BhXPxQSrgwg',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SFO'},
#        {'basisCode': 'QERT65',
#         'carrier': 'CM',
#         'destination': 'SAO',
#         'id': 'A2rEOP5EmjwVpqztYn2/7FkClMbbdF/NlXcWoxpR67C/Q',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'PTY'},
#        {'basisCode': 'COPP',
#         'carrier': 'AM',
#         'destination': 'SFO',
#         'id': 'Agb2IJMejflmxXatZkcS8kKgDi5/9mJhYXuqW4F/',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SAO'}],
#       'fareCalculation': 'SFO CM X/PTY Q80.00 Q15.00 592.00QWERT65 CM SAO Q40.00 642.00QERT65 AM X/MEX AM SFO Q SAOSFO65.00 1594.00COPP NUC 3028.00 END ROE 1.00 FARE USD 3028.00 XT 5.50YC 7.00XY 3.96XA 36.00US 5.60AY 1.25AH 35.70BR 0.80YR 4.50XF SFO4.50',
#       'kind': 'qpxexpress#pricingInfo',
#       'latestTicketingTime': '2017-05-11T23:59-04:00',
#       'passengers': {'adultCount': 1, 'kind': 'qpxexpress#passengerCounts'},
#       'ptc': 'ADT',
#       'refundable': True,
#       'saleFareTotal': 'USD3028.00',
#       'saleTaxTotal': 'USD100.31',
#       'saleTotal': 'USD3128.31',
#       'segmentPricing': [{'fareId': 'A2rEOP5EmjwVpqztYn2/7FkClMbbdF/NlXcWoxpR67C/Q',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'G9Tkq01pWC+Vi+Iq'},
#        {'fareId': 'A4Lag1ANi41XiQkx+LwWQsN3mFR7Zd8R8BhXPxQSrgwg',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'Gu5+lk0U0JH-9Ruh'},
#        {'fareId': 'Agb2IJMejflmxXatZkcS8kKgDi5/9mJhYXuqW4F/',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GJDMgR6PqK2ZsijP'},
#        {'fareId': 'Agb2IJMejflmxXatZkcS8kKgDi5/9mJhYXuqW4F/',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'G3-ufnEK3TRY3IEs'}],
#       'tax': [{'chargeType': 'GOVERNMENT',
#         'code': 'AH',
#         'country': 'PA',
#         'id': 'AH_003',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD1.25'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'AY',
#         'country': 'US',
#         'id': 'AY_001',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.60'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XF',
#         'country': 'US',
#         'id': 'XF',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD4.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XA',
#         'country': 'US',
#         'id': 'XA',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD3.96'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XY',
#         'country': 'US',
#         'id': 'XY',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD7.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'YC',
#         'country': 'US',
#         'id': 'YC',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'CARRIER_SURCHARGE',
#         'code': 'YR',
#         'id': 'YR_I',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD0.80'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'BR',
#         'country': 'BR',
#         'id': 'BR_004',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD35.70'}]}],
#     'saleTotal': 'USD3128.31',
#     'slice': [{'duration': 910,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'Q',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 40,
#         'duration': 441,
#         'flight': {'carrier': 'CM', 'number': '383'},
#         'id': 'Gu5+lk0U0JH-9Ruh',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-01T10:56-05:00',
#           'departureTime': '2017-07-01T01:35-07:00',
#           'destination': 'PTY',
#           'duration': 441,
#           'id': 'LYJ-eyeuBjnF9EN3',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'SFO',
#           'originTerminal': 'I',
#           'secure': True}],
#         'marriedSegmentGroup': '0'},
#        {'bookingCode': 'Q',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 429,
#         'flight': {'carrier': 'CM', 'number': '701'},
#         'id': 'G9Tkq01pWC+Vi+Iq',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-01T20:45-03:00',
#           'departureTime': '2017-07-01T11:36-05:00',
#           'destination': 'GRU',
#           'destinationTerminal': '2',
#           'duration': 429,
#           'id': 'LliOmCE6VgyW31yi',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'PTY'}],
#         'marriedSegmentGroup': '0'}]},
#      {'duration': 1595,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'C',
#         'bookingCodeCount': 7,
#         'cabin': 'BUSINESS',
#         'connectionDuration': 700,
#         'duration': 610,
#         'flight': {'carrier': 'AM', 'number': '15'},
#         'id': 'GJDMgR6PqK2ZsijP',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '777',
#           'arrivalTime': '2017-07-02T07:05-05:00',
#           'departureTime': '2017-07-01T22:55-03:00',
#           'destination': 'MEX',
#           'destinationTerminal': '2',
#           'duration': 610,
#           'id': 'LKuBVYWoO9eRatQU',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Alcoholic Beverages - Complimentary',
#           'mileage': 4616,
#           'origin': 'GRU',
#           'originTerminal': '2'}],
#         'marriedSegmentGroup': '1'},
#        {'bookingCode': 'C',
#         'bookingCodeCount': 7,
#         'cabin': 'BUSINESS',
#         'duration': 285,
#         'flight': {'carrier': 'AM', 'number': '664'},
#         'id': 'G3-ufnEK3TRY3IEs',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-02T21:30-07:00',
#           'departureTime': '2017-07-02T18:45-05:00',
#           'destination': 'SFO',
#           'destinationTerminal': 'I',
#           'duration': 285,
#           'id': 'LMldQ7hVf6IXaCB-',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Alcoholic Beverages - Complimentary',
#           'mileage': 1881,
#           'origin': 'MEX',
#           'originTerminal': '2',
#           'secure': True}],
#         'marriedSegmentGroup': '1'}]}]},
#    {'id': '1oWFUYz0DUSTGDeBQG7yX4007',
#     'kind': 'qpxexpress#tripOption',
#     'pricing': [{'baseFareTotal': 'USD3880.00',
#       'fare': [{'basisCode': 'QWERT65',
#         'carrier': 'CM',
#         'destination': 'PTY',
#         'id': 'A4Lag1ANi41XiQkx+LwWQsN3mFR7Zd8R8BhXPxQSrgwg',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SFO'},
#        {'basisCode': 'QERT65',
#         'carrier': 'CM',
#         'destination': 'SAO',
#         'id': 'A2rEOP5EmjwVpqztYn2/7FkClMbbdF/NlXcWoxpR67C/Q',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'PTY'},
#        {'basisCode': 'BHA0A9EN',
#         'carrier': 'AD',
#         'destination': 'SFO',
#         'id': 'AlAD/QywNjSlVKzMFN5uCNR+XPOXqD85FvA0XW1u5uAo',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SAO'}],
#       'fareCalculation': 'SFO CM X/PTY Q80.00 Q15.00 592.00QWERT65 CM SAO Q40.00 642.00QERT65 AD X/CHI Q65.00 UA SFO Q SAOSFO100.00 2346.00BHA0A9EN NUC 3880.00 END ROE 1.00 FARE USD 3880.00 XT 5.50YC 7.00XY 3.96XA 36.00US 5.60AY 1.25AH 35.70BR 9.00XF SFO4.50 ORD4.50',
#       'kind': 'qpxexpress#pricingInfo',
#       'latestTicketingTime': '2017-05-11T23:59-04:00',
#       'passengers': {'adultCount': 1, 'kind': 'qpxexpress#passengerCounts'},
#       'ptc': 'ADT',
#       'refundable': True,
#       'saleFareTotal': 'USD3880.00',
#       'saleTaxTotal': 'USD104.01',
#       'saleTotal': 'USD3984.01',
#       'segmentPricing': [{'fareId': 'A2rEOP5EmjwVpqztYn2/7FkClMbbdF/NlXcWoxpR67C/Q',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'G9Tkq01pWC+Vi+Iq'},
#        {'fareId': 'AlAD/QywNjSlVKzMFN5uCNR+XPOXqD85FvA0XW1u5uAo',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GvcQXeI2R-fzLaD+'},
#        {'fareId': 'A4Lag1ANi41XiQkx+LwWQsN3mFR7Zd8R8BhXPxQSrgwg',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'Gu5+lk0U0JH-9Ruh'},
#        {'fareId': 'AlAD/QywNjSlVKzMFN5uCNR+XPOXqD85FvA0XW1u5uAo',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GXA3+low7DXzGziG'}],
#       'tax': [{'chargeType': 'GOVERNMENT',
#         'code': 'AH',
#         'country': 'PA',
#         'id': 'AH_003',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD1.25'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'AY',
#         'country': 'US',
#         'id': 'AY_001',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.60'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XF',
#         'country': 'US',
#         'id': 'XF',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD9.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XA',
#         'country': 'US',
#         'id': 'XA',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD3.96'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XY',
#         'country': 'US',
#         'id': 'XY',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD7.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'YC',
#         'country': 'US',
#         'id': 'YC',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'BR',
#         'country': 'BR',
#         'id': 'BR_004',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD35.70'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'}]}],
#     'saleTotal': 'USD3984.01',
#     'slice': [{'duration': 910,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'Q',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 40,
#         'duration': 441,
#         'flight': {'carrier': 'CM', 'number': '383'},
#         'id': 'Gu5+lk0U0JH-9Ruh',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-01T10:56-05:00',
#           'departureTime': '2017-07-01T01:35-07:00',
#           'destination': 'PTY',
#           'duration': 441,
#           'id': 'LYJ-eyeuBjnF9EN3',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'SFO',
#           'originTerminal': 'I',
#           'secure': True}],
#         'marriedSegmentGroup': '0'},
#        {'bookingCode': 'Q',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 429,
#         'flight': {'carrier': 'CM', 'number': '701'},
#         'id': 'G9Tkq01pWC+Vi+Iq',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-01T20:45-03:00',
#           'departureTime': '2017-07-01T11:36-05:00',
#           'destination': 'GRU',
#           'destinationTerminal': '2',
#           'duration': 429,
#           'id': 'LliOmCE6VgyW31yi',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'PTY'}],
#         'marriedSegmentGroup': '0'}]},
#      {'duration': 1139,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'B',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 227,
#         'duration': 635,
#         'flight': {'carrier': 'AD', 'number': '7000'},
#         'id': 'GXA3+low7DXzGziG',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '777',
#           'arrivalTime': '2017-07-02T06:55-05:00',
#           'departureTime': '2017-07-01T22:20-03:00',
#           'destination': 'ORD',
#           'destinationTerminal': '1',
#           'duration': 635,
#           'id': 'LYHWF7N3ZbSpoWGf',
#           'kind': 'qpxexpress#legInfo',
#           'mileage': 5234,
#           'operatingDisclosure': 'OPERATED BY UNITED',
#           'origin': 'GRU',
#           'originTerminal': '3',
#           'secure': True}],
#         'marriedSegmentGroup': '1'},
#        {'bookingCode': 'W',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 277,
#         'flight': {'carrier': 'UA', 'number': '499'},
#         'id': 'GvcQXeI2R-fzLaD+',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '753',
#           'arrivalTime': '2017-07-02T13:19-07:00',
#           'departureTime': '2017-07-02T10:42-05:00',
#           'destination': 'SFO',
#           'destinationTerminal': '3',
#           'duration': 277,
#           'id': 'LjAsB7Q8G3dFng-H',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Food for Purchase',
#           'mileage': 1841,
#           'onTimePerformance': 70,
#           'origin': 'ORD',
#           'originTerminal': '1',
#           'secure': True}],
#         'marriedSegmentGroup': '2'}]}]},
#    {'id': '1oWFUYz0DUSTGDeBQG7yX4005',
#     'kind': 'qpxexpress#tripOption',
#     'pricing': [{'baseFareTotal': 'USD3880.00',
#       'fare': [{'basisCode': 'QWERT65',
#         'carrier': 'CM',
#         'destination': 'PTY',
#         'id': 'A4Lag1ANi41XiQkx+LwWQsN3mFR7Zd8R8BhXPxQSrgwg',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SFO'},
#        {'basisCode': 'QERT65',
#         'carrier': 'CM',
#         'destination': 'SAO',
#         'id': 'A2rEOP5EmjwVpqztYn2/7FkClMbbdF/NlXcWoxpR67C/Q',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'PTY'},
#        {'basisCode': 'BHA0A9EN',
#         'carrier': 'AD',
#         'destination': 'SFO',
#         'id': 'AlAD/QywNjSlVKzMFN5uCNR+XPOXqD85FvA0XW1u5uAo',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SAO'}],
#       'fareCalculation': 'SFO CM X/PTY Q80.00 Q15.00 592.00QWERT65 CM SAO Q40.00 642.00QERT65 AD X/CHI Q65.00 UA SFO Q SAOSFO100.00 2346.00BHA0A9EN NUC 3880.00 END ROE 1.00 FARE USD 3880.00 XT 5.50YC 7.00XY 3.96XA 36.00US 5.60AY 1.25AH 35.70BR 9.00XF SFO4.50 ORD4.50',
#       'kind': 'qpxexpress#pricingInfo',
#       'latestTicketingTime': '2017-05-11T23:59-04:00',
#       'passengers': {'adultCount': 1, 'kind': 'qpxexpress#passengerCounts'},
#       'ptc': 'ADT',
#       'refundable': True,
#       'saleFareTotal': 'USD3880.00',
#       'saleTaxTotal': 'USD104.01',
#       'saleTotal': 'USD3984.01',
#       'segmentPricing': [{'fareId': 'A2rEOP5EmjwVpqztYn2/7FkClMbbdF/NlXcWoxpR67C/Q',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'G9Tkq01pWC+Vi+Iq'},
#        {'fareId': 'A4Lag1ANi41XiQkx+LwWQsN3mFR7Zd8R8BhXPxQSrgwg',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'Gu5+lk0U0JH-9Ruh'},
#        {'fareId': 'AlAD/QywNjSlVKzMFN5uCNR+XPOXqD85FvA0XW1u5uAo',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GXA3+low7DXzGziG'},
#        {'fareId': 'AlAD/QywNjSlVKzMFN5uCNR+XPOXqD85FvA0XW1u5uAo',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GnrXA7HjSkSBlWWf'}],
#       'tax': [{'chargeType': 'GOVERNMENT',
#         'code': 'AH',
#         'country': 'PA',
#         'id': 'AH_003',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD1.25'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'AY',
#         'country': 'US',
#         'id': 'AY_001',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.60'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XF',
#         'country': 'US',
#         'id': 'XF',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD9.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XA',
#         'country': 'US',
#         'id': 'XA',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD3.96'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XY',
#         'country': 'US',
#         'id': 'XY',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD7.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'YC',
#         'country': 'US',
#         'id': 'YC',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'BR',
#         'country': 'BR',
#         'id': 'BR_004',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD35.70'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'}]}],
#     'saleTotal': 'USD3984.01',
#     'slice': [{'duration': 910,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'Q',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 40,
#         'duration': 441,
#         'flight': {'carrier': 'CM', 'number': '383'},
#         'id': 'Gu5+lk0U0JH-9Ruh',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-01T10:56-05:00',
#           'departureTime': '2017-07-01T01:35-07:00',
#           'destination': 'PTY',
#           'duration': 441,
#           'id': 'LYJ-eyeuBjnF9EN3',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'SFO',
#           'originTerminal': 'I',
#           'secure': True}],
#         'marriedSegmentGroup': '0'},
#        {'bookingCode': 'Q',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 429,
#         'flight': {'carrier': 'CM', 'number': '701'},
#         'id': 'G9Tkq01pWC+Vi+Iq',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-01T20:45-03:00',
#           'departureTime': '2017-07-01T11:36-05:00',
#           'destination': 'GRU',
#           'destinationTerminal': '2',
#           'duration': 429,
#           'id': 'LliOmCE6VgyW31yi',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'PTY'}],
#         'marriedSegmentGroup': '0'}]},
#      {'duration': 1050,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'B',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 135,
#         'duration': 635,
#         'flight': {'carrier': 'AD', 'number': '7000'},
#         'id': 'GXA3+low7DXzGziG',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '777',
#           'arrivalTime': '2017-07-02T06:55-05:00',
#           'departureTime': '2017-07-01T22:20-03:00',
#           'destination': 'ORD',
#           'destinationTerminal': '1',
#           'duration': 635,
#           'id': 'LYHWF7N3ZbSpoWGf',
#           'kind': 'qpxexpress#legInfo',
#           'mileage': 5234,
#           'operatingDisclosure': 'OPERATED BY UNITED',
#           'origin': 'GRU',
#           'originTerminal': '3',
#           'secure': True}],
#         'marriedSegmentGroup': '1'},
#        {'bookingCode': 'W',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 280,
#         'flight': {'carrier': 'UA', 'number': '769'},
#         'id': 'GnrXA7HjSkSBlWWf',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '777',
#           'arrivalTime': '2017-07-02T11:50-07:00',
#           'departureTime': '2017-07-02T09:10-05:00',
#           'destination': 'SFO',
#           'destinationTerminal': '3',
#           'duration': 280,
#           'id': 'LgoKaeU46q0sod72',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Food for Purchase',
#           'mileage': 1841,
#           'origin': 'ORD',
#           'originTerminal': '1',
#           'secure': True}],
#         'marriedSegmentGroup': '2'}]}]},
#    {'id': '1oWFUYz0DUSTGDeBQG7yX4009',
#     'kind': 'qpxexpress#tripOption',
#     'pricing': [{'baseFareTotal': 'USD3880.00',
#       'fare': [{'basisCode': 'QWERT65',
#         'carrier': 'CM',
#         'destination': 'PTY',
#         'id': 'A4Lag1ANi41XiQkx+LwWQsN3mFR7Zd8R8BhXPxQSrgwg',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SFO'},
#        {'basisCode': 'QERT65',
#         'carrier': 'CM',
#         'destination': 'SAO',
#         'id': 'A2rEOP5EmjwVpqztYn2/7FkClMbbdF/NlXcWoxpR67C/Q',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'PTY'},
#        {'basisCode': 'BHA0A9EN',
#         'carrier': 'AD',
#         'destination': 'SFO',
#         'id': 'AlAD/QywNjSlVKzMFN5uCNR+XPOXqD85FvA0XW1u5uAo',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SAO'}],
#       'fareCalculation': 'SFO CM X/PTY Q80.00 Q15.00 592.00QWERT65 CM SAO Q40.00 642.00QERT65 AD X/CHI Q65.00 UA SFO Q SAOSFO100.00 2346.00BHA0A9EN NUC 3880.00 END ROE 1.00 FARE USD 3880.00 XT 5.50YC 7.00XY 3.96XA 36.00US 5.60AY 1.25AH 35.70BR 9.00XF SFO4.50 ORD4.50',
#       'kind': 'qpxexpress#pricingInfo',
#       'latestTicketingTime': '2017-05-11T23:59-04:00',
#       'passengers': {'adultCount': 1, 'kind': 'qpxexpress#passengerCounts'},
#       'ptc': 'ADT',
#       'refundable': True,
#       'saleFareTotal': 'USD3880.00',
#       'saleTaxTotal': 'USD104.01',
#       'saleTotal': 'USD3984.01',
#       'segmentPricing': [{'fareId': 'A2rEOP5EmjwVpqztYn2/7FkClMbbdF/NlXcWoxpR67C/Q',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'G9Tkq01pWC+Vi+Iq'},
#        {'fareId': 'AlAD/QywNjSlVKzMFN5uCNR+XPOXqD85FvA0XW1u5uAo',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GhS5fzsgI8VIdog0'},
#        {'fareId': 'A4Lag1ANi41XiQkx+LwWQsN3mFR7Zd8R8BhXPxQSrgwg',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'Gu5+lk0U0JH-9Ruh'},
#        {'fareId': 'AlAD/QywNjSlVKzMFN5uCNR+XPOXqD85FvA0XW1u5uAo',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GXA3+low7DXzGziG'}],
#       'tax': [{'chargeType': 'GOVERNMENT',
#         'code': 'AH',
#         'country': 'PA',
#         'id': 'AH_003',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD1.25'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'AY',
#         'country': 'US',
#         'id': 'AY_001',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.60'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XF',
#         'country': 'US',
#         'id': 'XF',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD9.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XA',
#         'country': 'US',
#         'id': 'XA',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD3.96'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XY',
#         'country': 'US',
#         'id': 'XY',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD7.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'YC',
#         'country': 'US',
#         'id': 'YC',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'BR',
#         'country': 'BR',
#         'id': 'BR_004',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD35.70'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'}]}],
#     'saleTotal': 'USD3984.01',
#     'slice': [{'duration': 910,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'Q',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 40,
#         'duration': 441,
#         'flight': {'carrier': 'CM', 'number': '383'},
#         'id': 'Gu5+lk0U0JH-9Ruh',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-01T10:56-05:00',
#           'departureTime': '2017-07-01T01:35-07:00',
#           'destination': 'PTY',
#           'duration': 441,
#           'id': 'LYJ-eyeuBjnF9EN3',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'SFO',
#           'originTerminal': 'I',
#           'secure': True}],
#         'marriedSegmentGroup': '0'},
#        {'bookingCode': 'Q',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 429,
#         'flight': {'carrier': 'CM', 'number': '701'},
#         'id': 'G9Tkq01pWC+Vi+Iq',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-01T20:45-03:00',
#           'departureTime': '2017-07-01T11:36-05:00',
#           'destination': 'GRU',
#           'destinationTerminal': '2',
#           'duration': 429,
#           'id': 'LliOmCE6VgyW31yi',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'PTY'}],
#         'marriedSegmentGroup': '0'}]},
#      {'duration': 1231,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'B',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 320,
#         'duration': 635,
#         'flight': {'carrier': 'AD', 'number': '7000'},
#         'id': 'GXA3+low7DXzGziG',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '777',
#           'arrivalTime': '2017-07-02T06:55-05:00',
#           'departureTime': '2017-07-01T22:20-03:00',
#           'destination': 'ORD',
#           'destinationTerminal': '1',
#           'duration': 635,
#           'id': 'LYHWF7N3ZbSpoWGf',
#           'kind': 'qpxexpress#legInfo',
#           'mileage': 5234,
#           'operatingDisclosure': 'OPERATED BY UNITED',
#           'origin': 'GRU',
#           'originTerminal': '3',
#           'secure': True}],
#         'marriedSegmentGroup': '1'},
#        {'bookingCode': 'W',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 276,
#         'flight': {'carrier': 'UA', 'number': '312'},
#         'id': 'GhS5fzsgI8VIdog0',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '753',
#           'arrivalTime': '2017-07-02T14:51-07:00',
#           'departureTime': '2017-07-02T12:15-05:00',
#           'destination': 'SFO',
#           'destinationTerminal': '3',
#           'duration': 276,
#           'id': 'LYzswxTlRzbBVNnZ',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Food for Purchase',
#           'mileage': 1841,
#           'onTimePerformance': 70,
#           'origin': 'ORD',
#           'originTerminal': '1',
#           'secure': True}],
#         'marriedSegmentGroup': '2'}]}]},
#    {'id': '1oWFUYz0DUSTGDeBQG7yX4006',
#     'kind': 'qpxexpress#tripOption',
#     'pricing': [{'baseFareTotal': 'USD3972.00',
#       'fare': [{'basisCode': 'D07BC65',
#         'carrier': 'CM',
#         'destination': 'SAO',
#         'id': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SFO'},
#        {'basisCode': 'BNA0R9EY',
#         'carrier': 'UA',
#         'destination': 'CHI',
#         'id': 'AkZAJLgSlchCyzvXlc2Ky9yTWutcxOlRkiS6fhGu2ceY',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SAO'},
#        {'basisCode': 'QAA7AKEN',
#         'carrier': 'UA',
#         'destination': 'SFO',
#         'id': 'ABjxwDeMGZU7V+hMVtT4igNd9TOjq5JlTGHzpsjy4n5Y',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'CHI'}],
#       'fareCalculation': 'SFO CM X/PTY CM SAO Q SFOSAO65.00 921.00D07BC65 UA X/CHI Q65.00 M 2488.00BNA0R9EY UA SFO Q93.02 340.47QAA7AKEN NUC 3972.49 END ROE 1.00 FARE USD 3972.00 XT 5.50YC 7.00XY 3.96XA 36.00US 5.60AY 1.25AH 35.70BR 9.00XF SFO4.50 ORD4.50',
#       'kind': 'qpxexpress#pricingInfo',
#       'latestTicketingTime': '2017-05-09T23:59-04:00',
#       'passengers': {'adultCount': 1, 'kind': 'qpxexpress#passengerCounts'},
#       'ptc': 'ADT',
#       'refundable': True,
#       'saleFareTotal': 'USD3972.00',
#       'saleTaxTotal': 'USD104.01',
#       'saleTotal': 'USD4076.01',
#       'segmentPricing': [{'fareId': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'G9Tkq01pWC+Vi+Iq'},
#        {'fareId': 'ABjxwDeMGZU7V+hMVtT4igNd9TOjq5JlTGHzpsjy4n5Y',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GvcQXeI2R-fzLaD+'},
#        {'fareId': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'Gu5+lk0U0JH-9Ruh'},
#        {'fareId': 'AkZAJLgSlchCyzvXlc2Ky9yTWutcxOlRkiS6fhGu2ceY',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GI9Lttd22eqIch58'}],
#       'tax': [{'chargeType': 'GOVERNMENT',
#         'code': 'AH',
#         'country': 'PA',
#         'id': 'AH_003',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD1.25'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'AY',
#         'country': 'US',
#         'id': 'AY_001',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.60'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XF',
#         'country': 'US',
#         'id': 'XF',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD9.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XA',
#         'country': 'US',
#         'id': 'XA',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD3.96'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XY',
#         'country': 'US',
#         'id': 'XY',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD7.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'YC',
#         'country': 'US',
#         'id': 'YC',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'BR',
#         'country': 'BR',
#         'id': 'BR_004',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD35.70'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'}]}],
#     'saleTotal': 'USD4076.01',
#     'slice': [{'duration': 910,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'D',
#         'bookingCodeCount': 1,
#         'cabin': 'BUSINESS',
#         'connectionDuration': 40,
#         'duration': 441,
#         'flight': {'carrier': 'CM', 'number': '383'},
#         'id': 'Gu5+lk0U0JH-9Ruh',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-01T10:56-05:00',
#           'departureTime': '2017-07-01T01:35-07:00',
#           'destination': 'PTY',
#           'duration': 441,
#           'id': 'LYJ-eyeuBjnF9EN3',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'SFO',
#           'originTerminal': 'I',
#           'secure': True}],
#         'marriedSegmentGroup': '0'},
#        {'bookingCode': 'D',
#         'bookingCodeCount': 1,
#         'cabin': 'BUSINESS',
#         'duration': 429,
#         'flight': {'carrier': 'CM', 'number': '701'},
#         'id': 'G9Tkq01pWC+Vi+Iq',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
# ...
#           'id': 'LYJ-eyeuBjnF9EN3',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'SFO',
#           'originTerminal': 'I',
#           'secure': True}],
#         'marriedSegmentGroup': '0'},
#        {'bookingCode': 'D',
#         'bookingCodeCount': 1,
#         'cabin': 'BUSINESS',
#         'duration': 429,
#         'flight': {'carrier': 'CM', 'number': '701'},
#         'id': 'G9Tkq01pWC+Vi+Iq',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-01T20:45-03:00',
#           'departureTime': '2017-07-01T11:36-05:00',
#           'destination': 'GRU',
#           'destinationTerminal': '2',
#           'duration': 429,
#           'id': 'LliOmCE6VgyW31yi',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'PTY'}],
#         'marriedSegmentGroup': '0'}]},
#      {'duration': 1231,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'B',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 320,
#         'duration': 635,
#         'flight': {'carrier': 'UA', 'number': '844'},
#         'id': 'GI9Lttd22eqIch58',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '777',
#           'arrivalTime': '2017-07-02T06:55-05:00',
#           'departureTime': '2017-07-01T22:20-03:00',
#           'destination': 'ORD',
#           'destinationTerminal': '5',
#           'duration': 635,
#           'id': 'LOwsDYHGkodMx17D',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Dinner',
#           'mileage': 5234,
#           'origin': 'GRU',
#           'originTerminal': '3',
#           'secure': True}],
#         'marriedSegmentGroup': '1'},
#        {'bookingCode': 'Q',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 276,
#         'flight': {'carrier': 'UA', 'number': '312'},
#         'id': 'GhS5fzsgI8VIdog0',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '753',
#           'arrivalTime': '2017-07-02T14:51-07:00',
#           'departureTime': '2017-07-02T12:15-05:00',
#           'destination': 'SFO',
#           'destinationTerminal': '3',
#           'duration': 276,
#           'id': 'LYzswxTlRzbBVNnZ',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Food for Purchase',
#           'mileage': 1841,
#           'onTimePerformance': 70,
#           'origin': 'ORD',
#           'originTerminal': '1',
#           'secure': True}],
#         'marriedSegmentGroup': '2'}]}]},
#    {'id': '1oWFUYz0DUSTGDeBQG7yX400A',
#     'kind': 'qpxexpress#tripOption',
#     'pricing': [{'baseFareTotal': 'USD3972.00',
#       'fare': [{'basisCode': 'D07BC65',
#         'carrier': 'CM',
#         'destination': 'SAO',
#         'id': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SFO'},
#        {'basisCode': 'BNA0R9EY',
#         'carrier': 'UA',
#         'destination': 'CHI',
#         'id': 'AkZAJLgSlchCyzvXlc2Ky9yTWutcxOlRkiS6fhGu2ceY',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SAO'},
#        {'basisCode': 'QAA7AKEN',
#         'carrier': 'UA',
#         'destination': 'SFO',
#         'id': 'ABjxwDeMGZU7V+hMVtT4igNd9TOjq5JlTGHzpsjy4n5Y',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'CHI'}],
#       'fareCalculation': 'SFO CM X/PTY CM SAO Q SFOSAO65.00 921.00D07BC65 UA X/CHI Q65.00 M 2488.00BNA0R9EY UA SFO Q93.02 340.47QAA7AKEN NUC 3972.49 END ROE 1.00 FARE USD 3972.00 XT 5.50YC 7.00XY 3.96XA 36.00US 5.60AY 1.25AH 35.70BR 9.00XF SFO4.50 ORD4.50',
#       'kind': 'qpxexpress#pricingInfo',
#       'latestTicketingTime': '2017-05-09T23:59-04:00',
#       'passengers': {'adultCount': 1, 'kind': 'qpxexpress#passengerCounts'},
#       'ptc': 'ADT',
#       'refundable': True,
#       'saleFareTotal': 'USD3972.00',
#       'saleTaxTotal': 'USD104.01',
#       'saleTotal': 'USD4076.01',
#       'segmentPricing': [{'fareId': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'G9Tkq01pWC+Vi+Iq'},
#        {'fareId': 'ABjxwDeMGZU7V+hMVtT4igNd9TOjq5JlTGHzpsjy4n5Y',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GoHgvKmASCjQPNoN'},
#        {'fareId': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'Gu5+lk0U0JH-9Ruh'},
#        {'fareId': 'AkZAJLgSlchCyzvXlc2Ky9yTWutcxOlRkiS6fhGu2ceY',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GI9Lttd22eqIch58'}],
#       'tax': [{'chargeType': 'GOVERNMENT',
#         'code': 'AH',
#         'country': 'PA',
#         'id': 'AH_003',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD1.25'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'AY',
#         'country': 'US',
#         'id': 'AY_001',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.60'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XF',
#         'country': 'US',
#         'id': 'XF',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD9.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XA',
#         'country': 'US',
#         'id': 'XA',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD3.96'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XY',
#         'country': 'US',
#         'id': 'XY',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD7.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'YC',
#         'country': 'US',
#         'id': 'YC',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'BR',
#         'country': 'BR',
#         'id': 'BR_004',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD35.70'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'}]}],
#     'saleTotal': 'USD4076.01',
#     'slice': [{'duration': 910,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'D',
#         'bookingCodeCount': 1,
#         'cabin': 'BUSINESS',
#         'connectionDuration': 40,
#         'duration': 441,
#         'flight': {'carrier': 'CM', 'number': '383'},
#         'id': 'Gu5+lk0U0JH-9Ruh',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-01T10:56-05:00',
#           'departureTime': '2017-07-01T01:35-07:00',
#           'destination': 'PTY',
#           'duration': 441,
#           'id': 'LYJ-eyeuBjnF9EN3',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'SFO',
#           'originTerminal': 'I',
#           'secure': True}],
#         'marriedSegmentGroup': '0'},
#        {'bookingCode': 'D',
#         'bookingCodeCount': 1,
#         'cabin': 'BUSINESS',
#         'duration': 429,
#         'flight': {'carrier': 'CM', 'number': '701'},
#         'id': 'G9Tkq01pWC+Vi+Iq',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-01T20:45-03:00',
#           'departureTime': '2017-07-01T11:36-05:00',
#           'destination': 'GRU',
#           'destinationTerminal': '2',
#           'duration': 429,
#           'id': 'LliOmCE6VgyW31yi',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'PTY'}],
#         'marriedSegmentGroup': '0'}]},
#      {'duration': 1342,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'B',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 430,
#         'duration': 635,
#         'flight': {'carrier': 'UA', 'number': '844'},
#         'id': 'GI9Lttd22eqIch58',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '777',
#           'arrivalTime': '2017-07-02T06:55-05:00',
#           'departureTime': '2017-07-01T22:20-03:00',
#           'destination': 'ORD',
#           'destinationTerminal': '5',
#           'duration': 635,
#           'id': 'LOwsDYHGkodMx17D',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Dinner',
#           'mileage': 5234,
#           'origin': 'GRU',
#           'originTerminal': '3',
#           'secure': True}],
#         'marriedSegmentGroup': '1'},
#        {'bookingCode': 'Q',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 277,
#         'flight': {'carrier': 'UA', 'number': '222'},
#         'id': 'GoHgvKmASCjQPNoN',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '753',
#           'arrivalTime': '2017-07-02T16:42-07:00',
#           'departureTime': '2017-07-02T14:05-05:00',
#           'destination': 'SFO',
#           'destinationTerminal': '3',
#           'duration': 277,
#           'id': 'LhmDFsihwTqzsCxj',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Food for Purchase',
#           'mileage': 1841,
#           'onTimePerformance': 70,
#           'origin': 'ORD',
#           'originTerminal': '1',
#           'secure': True}],
#         'marriedSegmentGroup': '2'}]}]},
#    {'id': '1oWFUYz0DUSTGDeBQG7yX4004',
#     'kind': 'qpxexpress#tripOption',
#     'pricing': [{'baseFareTotal': 'USD3972.00',
#       'fare': [{'basisCode': 'D07BC65',
#         'carrier': 'CM',
#         'destination': 'SAO',
#         'id': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SFO'},
#        {'basisCode': 'BNA0R9EY',
#         'carrier': 'UA',
#         'destination': 'CHI',
#         'id': 'AkZAJLgSlchCyzvXlc2Ky9yTWutcxOlRkiS6fhGu2ceY',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'SAO'},
#        {'basisCode': 'QAA7AKEN',
#         'carrier': 'UA',
#         'destination': 'SFO',
#         'id': 'ABjxwDeMGZU7V+hMVtT4igNd9TOjq5JlTGHzpsjy4n5Y',
#         'kind': 'qpxexpress#fareInfo',
#         'origin': 'CHI'}],
#       'fareCalculation': 'SFO CM X/PTY CM SAO Q SFOSAO65.00 921.00D07BC65 UA X/CHI Q65.00 M 2488.00BNA0R9EY UA SFO Q93.02 340.47QAA7AKEN NUC 3972.49 END ROE 1.00 FARE USD 3972.00 XT 5.50YC 7.00XY 3.96XA 36.00US 5.60AY 1.25AH 35.70BR 9.00XF SFO4.50 ORD4.50',
#       'kind': 'qpxexpress#pricingInfo',
#       'latestTicketingTime': '2017-05-09T23:59-04:00',
#       'passengers': {'adultCount': 1, 'kind': 'qpxexpress#passengerCounts'},
#       'ptc': 'ADT',
#       'refundable': True,
#       'saleFareTotal': 'USD3972.00',
#       'saleTaxTotal': 'USD104.01',
#       'saleTotal': 'USD4076.01',
#       'segmentPricing': [{'fareId': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'G9Tkq01pWC+Vi+Iq'},
#        {'fareId': 'Ak/NZkqxr29SFKPqK1fof6WajQOu2uJiCVISmVA89tJA',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'Gu5+lk0U0JH-9Ruh'},
#        {'fareId': 'AkZAJLgSlchCyzvXlc2Ky9yTWutcxOlRkiS6fhGu2ceY',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GI9Lttd22eqIch58'},
#        {'fareId': 'ABjxwDeMGZU7V+hMVtT4igNd9TOjq5JlTGHzpsjy4n5Y',
#         'kind': 'qpxexpress#segmentPricing',
#         'segmentId': 'GnrXA7HjSkSBlWWf'}],
#       'tax': [{'chargeType': 'GOVERNMENT',
#         'code': 'AH',
#         'country': 'PA',
#         'id': 'AH_003',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD1.25'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'AY',
#         'country': 'US',
#         'id': 'AY_001',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.60'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XF',
#         'country': 'US',
#         'id': 'XF',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD9.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XA',
#         'country': 'US',
#         'id': 'XA',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD3.96'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'XY',
#         'country': 'US',
#         'id': 'XY',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD7.00'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'YC',
#         'country': 'US',
#         'id': 'YC',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD5.50'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'BR',
#         'country': 'BR',
#         'id': 'BR_004',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD35.70'},
#        {'chargeType': 'GOVERNMENT',
#         'code': 'US',
#         'country': 'US',
#         'id': 'US_002',
#         'kind': 'qpxexpress#taxInfo',
#         'salePrice': 'USD18.00'}]}],
#     'saleTotal': 'USD4076.01',
#     'slice': [{'duration': 910,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'D',
#         'bookingCodeCount': 1,
#         'cabin': 'BUSINESS',
#         'connectionDuration': 40,
#         'duration': 441,
#         'flight': {'carrier': 'CM', 'number': '383'},
#         'id': 'Gu5+lk0U0JH-9Ruh',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-01T10:56-05:00',
#           'departureTime': '2017-07-01T01:35-07:00',
#           'destination': 'PTY',
#           'duration': 441,
#           'id': 'LYJ-eyeuBjnF9EN3',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3319,
#           'origin': 'SFO',
#           'originTerminal': 'I',
#           'secure': True}],
#         'marriedSegmentGroup': '0'},
#        {'bookingCode': 'D',
#         'bookingCodeCount': 1,
#         'cabin': 'BUSINESS',
#         'duration': 429,
#         'flight': {'carrier': 'CM', 'number': '701'},
#         'id': 'G9Tkq01pWC+Vi+Iq',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '738',
#           'arrivalTime': '2017-07-01T20:45-03:00',
#           'departureTime': '2017-07-01T11:36-05:00',
#           'destination': 'GRU',
#           'destinationTerminal': '2',
#           'duration': 429,
#           'id': 'LliOmCE6VgyW31yi',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Meal',
#           'mileage': 3158,
#           'origin': 'PTY'}],
#         'marriedSegmentGroup': '0'}]},
#      {'duration': 1050,
#       'kind': 'qpxexpress#sliceInfo',
#       'segment': [{'bookingCode': 'B',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'connectionDuration': 135,
#         'duration': 635,
#         'flight': {'carrier': 'UA', 'number': '844'},
#         'id': 'GI9Lttd22eqIch58',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '777',
#           'arrivalTime': '2017-07-02T06:55-05:00',
#           'departureTime': '2017-07-01T22:20-03:00',
#           'destination': 'ORD',
#           'destinationTerminal': '5',
#           'duration': 635,
#           'id': 'LOwsDYHGkodMx17D',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Dinner',
#           'mileage': 5234,
#           'origin': 'GRU',
#           'originTerminal': '3',
#           'secure': True}],
#         'marriedSegmentGroup': '1'},
#        {'bookingCode': 'Q',
#         'bookingCodeCount': 9,
#         'cabin': 'COACH',
#         'duration': 280,
#         'flight': {'carrier': 'UA', 'number': '769'},
#         'id': 'GnrXA7HjSkSBlWWf',
#         'kind': 'qpxexpress#segmentInfo',
#         'leg': [{'aircraft': '777',
#           'arrivalTime': '2017-07-02T11:50-07:00',
#           'departureTime': '2017-07-02T09:10-05:00',
#           'destination': 'SFO',
#           'destinationTerminal': '3',
#           'duration': 280,
#           'id': 'LgoKaeU46q0sod72',
#           'kind': 'qpxexpress#legInfo',
#           'meal': 'Food for Purchase',
#           'mileage': 1841,
#           'origin': 'ORD',
#           'originTerminal': '1',
#           'secure': True}],
#         'marriedSegmentGroup': '2'}]}]}]}}

# %% [markdown]
# ### Check the number of files and size in my S3 bucket

# %%
aws s3 ls --summarize --human-readable --recursive s3://qpxexpress/2017

# %% [markdown]
# <img src="images/bucket_size.png">
